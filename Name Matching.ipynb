# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
import string
from string import digits
import math
from scipy import spatial
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
from scipy import spatial
from numpy import dot
import matplotlib
import matplotlib.pyplot as plt
from numpy.linalg import norm
from sklearn.metrics import confusion_matrix
import jellyfish
import seaborn as sns
from collections import Counter
from metaphone import doublemetaphone
import enchant
import glob
import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload 
# %autoreload 2

# %%
# Reading the OFAC List
OFAC_list = pd.read_csv('https://www.treasury.gov/ofac/downloads/sdn.csv', header = None) # OFAC always uses this precise link
OFAC_list
# Out:
#           0                                             1           2   \
# 0         36                        AEROCARIBBEAN AIRLINES        -0-
# 1        173                     ANGLO-CARIBBEAN CO., LTD.        -0-
# 2        306                        BANCO NACIONAL DE CUBA        -0-
# 3        424                            BOUTIQUE LA MAISON        -0-
# 4        475                                  CASA DE CUBA        -0-
# ...      ...                                           ...         ...
# 10151  37184                                  KARDIAN, Ari  individual
# 10152  37185  JOINT STOCK COMPANY NTV BROADCASTING COMPANY        -0-
# 10153  37196                   TELEVISION STATION RUSSIA-1        -0-
# 10154  37197        JOINT STOCK COMPANY CHANNEL ONE RUSSIA        -0-
# 10155                                                 NaN         NaN
#
#                    3     4     5     6     7     8     9     10  \
# 0                CUBA  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 1                CUBA  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 2                CUBA  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 3                CUBA  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 4                CUBA  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# ...               ...   ...   ...   ...   ...   ...   ...   ...
# 10151            SDGT  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 10152  RUSSIA-EO14024  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 10153  RUSSIA-EO14024  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 10154  RUSSIA-EO14024  -0-   -0-   -0-   -0-   -0-   -0-   -0-
# 10155             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                                                       11
# 0                                                   -0-
# 1                                                   -0-
# 2                                          a.k.a. 'BNC'.
# 3                                                   -0-
# 4                                                   -0-
# ...                                                  ...
# 10151  DOB 16 Feb 1990; POB Tasikmalaya, West Java, I...
# 10152  Organization Established Date 1993; Tax ID No....
# 10153  Organization Established Date 13 May 1991; Tar...
# 10154  Tax ID No. 7717039300 (Russia); Registration N...
# 10155                                                NaN
#
# [10156 rows x 12 columns]

# %%
# Filtering Individuals out of the OFAC List
df_individuals = OFAC_list[OFAC_list[2] == 'individual'].reset_index()
df_individuals.shape[0]
# Out:
# 5244

# %%
# Printing the Individual Rows
df_individuals
# Out:
#       index      0                                    1           2     3  \
# 0        53   2674                           ABBAS, Abu  individual  SDGT
# 1        54   2675           AL RAHMAN, Shaykh Umar Abd  individual  SDGT
# 2        55   2676               AL ZAWAHIRI, Dr. Ayman  individual  SDGT
# 3        56   2677  AL-ZOMOR, Abboud Abdul Latif Hassan  individual  SDGT
# 4        57   2678                    AWDA, Abd Al Aziz  individual  SDGT
# ...     ...    ...                                  ...         ...   ...
# 5239  10147  37180             ADHIGUNA, Muhammad Dandi  individual  SDGT
# 5240  10148  37181                      RAMADHANI, Dini  individual  SDGT
# 5241  10149  37182                  SUSANTI, Dwi Dahlia  individual  SDGT
# 5242  10150  37183                        HERYADI, Rudi  individual  SDGT
# 5243  10151  37184                         KARDIAN, Ari  individual  SDGT
#
#                                                       4     5     6     7  \
# 0     Director of PALESTINE LIBERATION FRONT - ABU A...  -0-   -0-   -0-
# 1           Chief Ideological Figure of ISLAMIC GAMA'AT  -0-   -0-   -0-
# 2        Operational and Military Leader of JIHAD GROUP  -0-   -0-   -0-
# 3                                                  -0-   -0-   -0-   -0-
# 4     Chief Ideological Figure of PALESTINIAN ISLAMI...  -0-   -0-   -0-
# ...                                                 ...   ...   ...   ...
# 5239                                               -0-   -0-   -0-   -0-
# 5240                                               -0-   -0-   -0-   -0-
# 5241                                               -0-   -0-   -0-   -0-
# 5242                                               -0-   -0-   -0-   -0-
# 5243                                               -0-   -0-   -0-   -0-
#
#          8     9    10                                                 11
# 0     -0-   -0-   -0-   DOB 10 Dec 1948; Director of PALESTINE LIBERAT...
# 1     -0-   -0-   -0-   DOB 03 May 1938; POB Egypt; Chief Ideological ...
# 2     -0-   -0-   -0-   DOB 19 Jun 1951; POB Giza, Egypt; Passport 108...
# 3     -0-   -0-   -0-   DOB 19 Apr 1947; POB Nahia, Giza, Egypt; natio...
# 4     -0-   -0-   -0-   DOB 1946; Chief Ideological Figure of PALESTIN...
# ...    ...   ...   ...                                                ...
# 5239  -0-   -0-   -0-   DOB 30 Jul 1996; POB Gresik, East Java, Indone...
# 5240  -0-   -0-   -0-   DOB 10 Mar 1993; nationality Indonesia; Gender...
# 5241  -0-   -0-   -0-   DOB 28 Jul 1976; nationality Indonesia; Gender...
# 5242  -0-   -0-   -0-   DOB 21 Sep 1973; POB Cirebon, West Java, Indon...
# 5243  -0-   -0-   -0-   DOB 16 Feb 1990; POB Tasikmalaya, West Java, I...
#
# [5244 rows x 13 columns]

# %%
# Changing column names to make them easier to work with: 
df_individuals = df_individuals.rename(columns = {1 : 'OFAC_Name', 2: 'Entity Type'})

# %%
# Checking the previous implementation
df_individuals
# Out:
#       index      0                            OFAC_Name Entity Type     3  \
# 0        53   2674                           ABBAS, Abu  individual  SDGT
# 1        54   2675           AL RAHMAN, Shaykh Umar Abd  individual  SDGT
# 2        55   2676               AL ZAWAHIRI, Dr. Ayman  individual  SDGT
# 3        56   2677  AL-ZOMOR, Abboud Abdul Latif Hassan  individual  SDGT
# 4        57   2678                    AWDA, Abd Al Aziz  individual  SDGT
# ...     ...    ...                                  ...         ...   ...
# 5239  10147  37180             ADHIGUNA, Muhammad Dandi  individual  SDGT
# 5240  10148  37181                      RAMADHANI, Dini  individual  SDGT
# 5241  10149  37182                  SUSANTI, Dwi Dahlia  individual  SDGT
# 5242  10150  37183                        HERYADI, Rudi  individual  SDGT
# 5243  10151  37184                         KARDIAN, Ari  individual  SDGT
#
#                                                       4     5     6     7  \
# 0     Director of PALESTINE LIBERATION FRONT - ABU A...  -0-   -0-   -0-
# 1           Chief Ideological Figure of ISLAMIC GAMA'AT  -0-   -0-   -0-
# 2        Operational and Military Leader of JIHAD GROUP  -0-   -0-   -0-
# 3                                                  -0-   -0-   -0-   -0-
# 4     Chief Ideological Figure of PALESTINIAN ISLAMI...  -0-   -0-   -0-
# ...                                                 ...   ...   ...   ...
# 5239                                               -0-   -0-   -0-   -0-
# 5240                                               -0-   -0-   -0-   -0-
# 5241                                               -0-   -0-   -0-   -0-
# 5242                                               -0-   -0-   -0-   -0-
# 5243                                               -0-   -0-   -0-   -0-
#
#          8     9    10                                                 11
# 0     -0-   -0-   -0-   DOB 10 Dec 1948; Director of PALESTINE LIBERAT...
# 1     -0-   -0-   -0-   DOB 03 May 1938; POB Egypt; Chief Ideological ...
# 2     -0-   -0-   -0-   DOB 19 Jun 1951; POB Giza, Egypt; Passport 108...
# 3     -0-   -0-   -0-   DOB 19 Apr 1947; POB Nahia, Giza, Egypt; natio...
# 4     -0-   -0-   -0-   DOB 1946; Chief Ideological Figure of PALESTIN...
# ...    ...   ...   ...                                                ...
# 5239  -0-   -0-   -0-   DOB 30 Jul 1996; POB Gresik, East Java, Indone...
# 5240  -0-   -0-   -0-   DOB 10 Mar 1993; nationality Indonesia; Gender...
# 5241  -0-   -0-   -0-   DOB 28 Jul 1976; nationality Indonesia; Gender...
# 5242  -0-   -0-   -0-   DOB 21 Sep 1973; POB Cirebon, West Java, Indon...
# 5243  -0-   -0-   -0-   DOB 16 Feb 1990; POB Tasikmalaya, West Java, I...
#
# [5244 rows x 13 columns]

# %%
# Function to switch the Name Order from Last, First Middle --> First Middle Last
def first_name_before_last_name(Orignal_name):
    name_=''
    temp=''
    for i in Orignal_name.lower():
        if i == ',':
            temp=name_
            name_=''
        else:
            name_+=i
    return str.strip(name_+' '+temp)

# %%
# Puts Last name: Barge after First name: Neel and coverts the name to lowercase
first_name_before_last_name('Barge, Neel')
# Out:
# 'neel barge'

# %%
# Keeps the name as is if it is already in the First Middle Last order
first_name_before_last_name('Neel Barge')
# Out:
# 'neel barge'

# %%
# Adds a column 'OFAC_Name_First_Last' with OFAC Names in the order First Middle Last Name
df_individuals['OFAC_Name_First_Last']=''
for i in range(len(df_individuals['OFAC_Name'])):
    df_individuals['OFAC_Name_First_Last'].iloc[i] = first_name_before_last_name(df_individuals['OFAC_Name'][i])

# %%
df_individuals
# Out:
#       index      0                            OFAC_Name Entity Type     3  \
# 0        53   2674                           ABBAS, Abu  individual  SDGT
# 1        54   2675           AL RAHMAN, Shaykh Umar Abd  individual  SDGT
# 2        55   2676               AL ZAWAHIRI, Dr. Ayman  individual  SDGT
# 3        56   2677  AL-ZOMOR, Abboud Abdul Latif Hassan  individual  SDGT
# 4        57   2678                    AWDA, Abd Al Aziz  individual  SDGT
# ...     ...    ...                                  ...         ...   ...
# 5239  10147  37180             ADHIGUNA, Muhammad Dandi  individual  SDGT
# 5240  10148  37181                      RAMADHANI, Dini  individual  SDGT
# 5241  10149  37182                  SUSANTI, Dwi Dahlia  individual  SDGT
# 5242  10150  37183                        HERYADI, Rudi  individual  SDGT
# 5243  10151  37184                         KARDIAN, Ari  individual  SDGT
#
#                                                       4     5     6     7  \
# 0     Director of PALESTINE LIBERATION FRONT - ABU A...  -0-   -0-   -0-
# 1           Chief Ideological Figure of ISLAMIC GAMA'AT  -0-   -0-   -0-
# 2        Operational and Military Leader of JIHAD GROUP  -0-   -0-   -0-
# 3                                                  -0-   -0-   -0-   -0-
# 4     Chief Ideological Figure of PALESTINIAN ISLAMI...  -0-   -0-   -0-
# ...                                                 ...   ...   ...   ...
# 5239                                               -0-   -0-   -0-   -0-
# 5240                                               -0-   -0-   -0-   -0-
# 5241                                               -0-   -0-   -0-   -0-
# 5242                                               -0-   -0-   -0-   -0-
# 5243                                               -0-   -0-   -0-   -0-
#
#          8     9    10                                                 11  \
# 0     -0-   -0-   -0-   DOB 10 Dec 1948; Director of PALESTINE LIBERAT...
# 1     -0-   -0-   -0-   DOB 03 May 1938; POB Egypt; Chief Ideological ...
# 2     -0-   -0-   -0-   DOB 19 Jun 1951; POB Giza, Egypt; Passport 108...
# 3     -0-   -0-   -0-   DOB 19 Apr 1947; POB Nahia, Giza, Egypt; natio...
# 4     -0-   -0-   -0-   DOB 1946; Chief Ideological Figure of PALESTIN...
# ...    ...   ...   ...                                                ...
# 5239  -0-   -0-   -0-   DOB 30 Jul 1996; POB Gresik, East Java, Indone...
# 5240  -0-   -0-   -0-   DOB 10 Mar 1993; nationality Indonesia; Gender...
# 5241  -0-   -0-   -0-   DOB 28 Jul 1976; nationality Indonesia; Gender...
# 5242  -0-   -0-   -0-   DOB 21 Sep 1973; POB Cirebon, West Java, Indon...
# 5243  -0-   -0-   -0-   DOB 16 Feb 1990; POB Tasikmalaya, West Java, I...
#
#                     OFAC_Name_First_Last
# 0                              abu abbas
# 1              shaykh umar abd al rahman
# 2                  dr. ayman al zawahiri
# 3     abboud abdul latif hassan al-zomor
# 4                       abd al aziz awda
# ...                                  ...
# 5239             muhammad dandi adhiguna
# 5240                      dini ramadhani
# 5241                  dwi dahlia susanti
# 5242                        rudi heryadi
# 5243                         ari kardian
#
# [5244 rows x 14 columns]

# %%
# Removes digits from the Name Variations and makes a separate column for them
def remove_numbers(dataframe, column_name, digits_column):
    dataframe[f'{digits_column}'] = ''
    for i in range(len(dataframe)):
        for c in dataframe[f'{column_name}'][i]: 
            # Moving digits to a different column called Name_variation_digits:
            if c.isdigit():
                dataframe[f'{digits_column}'][i] += c
        # Removing digits from the original Name_variation column
        dataframe[f'{column_name}'][i] = dataframe[f'{column_name}'][i].translate(str.maketrans('', '', string.digits))

# %%
# Converts the string to lowercase, removes punctuations
def column_cleaning(dataframe, column_name, clean_column_name):
    dataframe[f'{clean_column_name}'] = ''
    for i in range(len(dataframe)):
        dataframe[f'{clean_column_name}'][i] = str(dataframe[f'{column_name}'][i]) \
            .lower() \
            .translate(str.maketrans('', '', string.punctuation)) \
            .replace("‘", '') \
            .replace('’', '')

# %%
# Adds a new column to the OFAC List with punctuations removed 
column_cleaning(df_individuals, 'OFAC_Name_First_Last', 'OFAC_Name_Clean')

# %%
# 'OFAC_Name_Clean' column added with punctuations removed
df_individuals
# Out:
#       index      0                            OFAC_Name Entity Type     3  \
# 0        53   2674                           ABBAS, Abu  individual  SDGT
# 1        54   2675           AL RAHMAN, Shaykh Umar Abd  individual  SDGT
# 2        55   2676               AL ZAWAHIRI, Dr. Ayman  individual  SDGT
# 3        56   2677  AL-ZOMOR, Abboud Abdul Latif Hassan  individual  SDGT
# 4        57   2678                    AWDA, Abd Al Aziz  individual  SDGT
# ...     ...    ...                                  ...         ...   ...
# 5239  10147  37180             ADHIGUNA, Muhammad Dandi  individual  SDGT
# 5240  10148  37181                      RAMADHANI, Dini  individual  SDGT
# 5241  10149  37182                  SUSANTI, Dwi Dahlia  individual  SDGT
# 5242  10150  37183                        HERYADI, Rudi  individual  SDGT
# 5243  10151  37184                         KARDIAN, Ari  individual  SDGT
#
#                                                       4     5     6     7  \
# 0     Director of PALESTINE LIBERATION FRONT - ABU A...  -0-   -0-   -0-
# 1           Chief Ideological Figure of ISLAMIC GAMA'AT  -0-   -0-   -0-
# 2        Operational and Military Leader of JIHAD GROUP  -0-   -0-   -0-
# 3                                                  -0-   -0-   -0-   -0-
# 4     Chief Ideological Figure of PALESTINIAN ISLAMI...  -0-   -0-   -0-
# ...                                                 ...   ...   ...   ...
# 5239                                               -0-   -0-   -0-   -0-
# 5240                                               -0-   -0-   -0-   -0-
# 5241                                               -0-   -0-   -0-   -0-
# 5242                                               -0-   -0-   -0-   -0-
# 5243                                               -0-   -0-   -0-   -0-
#
#          8     9    10                                                 11  \
# 0     -0-   -0-   -0-   DOB 10 Dec 1948; Director of PALESTINE LIBERAT...
# 1     -0-   -0-   -0-   DOB 03 May 1938; POB Egypt; Chief Ideological ...
# 2     -0-   -0-   -0-   DOB 19 Jun 1951; POB Giza, Egypt; Passport 108...
# 3     -0-   -0-   -0-   DOB 19 Apr 1947; POB Nahia, Giza, Egypt; natio...
# 4     -0-   -0-   -0-   DOB 1946; Chief Ideological Figure of PALESTIN...
# ...    ...   ...   ...                                                ...
# 5239  -0-   -0-   -0-   DOB 30 Jul 1996; POB Gresik, East Java, Indone...
# 5240  -0-   -0-   -0-   DOB 10 Mar 1993; nationality Indonesia; Gender...
# 5241  -0-   -0-   -0-   DOB 28 Jul 1976; nationality Indonesia; Gender...
# 5242  -0-   -0-   -0-   DOB 21 Sep 1973; POB Cirebon, West Java, Indon...
# 5243  -0-   -0-   -0-   DOB 16 Feb 1990; POB Tasikmalaya, West Java, I...
#
#                     OFAC_Name_First_Last                    OFAC_Name_Clean
# 0                              abu abbas                          abu abbas
# 1              shaykh umar abd al rahman          shaykh umar abd al rahman
# 2                  dr. ayman al zawahiri               dr ayman al zawahiri
# 3     abboud abdul latif hassan al-zomor  abboud abdul latif hassan alzomor
# 4                       abd al aziz awda                   abd al aziz awda
# ...                                  ...                                ...
# 5239             muhammad dandi adhiguna            muhammad dandi adhiguna
# 5240                      dini ramadhani                     dini ramadhani
# 5241                  dwi dahlia susanti                 dwi dahlia susanti
# 5242                        rudi heryadi                       rudi heryadi
# 5243                         ari kardian                        ari kardian
#
# [5244 rows x 15 columns]

# %%
# Storing all the OFAC Names in the OFAC_List
# Storing the OFAC_Name_Clean in the OFAC_Name_Clean_List
OFAC_List=[]
OFAC_Name_Clean_List = []
for ofac_name, ofac_name_clean in zip(df_individuals['OFAC_Name'], df_individuals['OFAC_Name_Clean']):
    OFAC_List.append(ofac_name.lower())
    OFAC_Name_Clean_List.append(first_name_before_last_name(ofac_name))
print(len(OFAC_List))
print(len(OFAC_Name_Clean_List))
print(OFAC_List)
print(OFAC_Name_Clean_List)
# Out:
# 5244
# 5244
# ['abbas, abu', 'al rahman, shaykh umar abd', 'al zawahiri, dr. ayman', 'al-zomor, abboud abdul latif hassan', 'awda, abd al aziz', 'fadlallah, shaykh muhammad husayn', 'hawatma, nayif', 'islambouli, mohammad shawqi', 'jabril, ahmad', 'naji, talal muhammad rashid', 'nasrallah, hasan', 'tufayli, subhi', 'yassin, sheik ahmed ismail', 'abu marzook, mousa mohammed', 'rodriguez orejuela, gilberto jose', 'rodriguez orejuela, miguel angel', 'abdallah, ramadan', 'nasser david, julio cesar', 'nasser arana, carlos alberto', 'nasser arana, claudia patricia', 'nasser arana, jorge', 'bin ladin, usama bin muhammad bin awad', 'al-masri, abu hafs', "musa, rifa'i ahmad taha", 'omar, mohammed', 'urdinola grajales, ivan', 'urdinola grajales, julio fabio', 'henao montoya, lorena', 'amezcua contreras, jose de jesus', 'amezcua contreras, luis ignacio', 'arellano felix, ramon eduardo', 'caro quintero, rafael', 'carrillo fuentes, vicente', 'chang, chi fu', 'heath, noel timothy', 'ogungbuyi, oluwole a.', 'ogungbuyi, abeni o.', 'wei, hsueh kang', 'arellano felix, benjamin alberto', 'henao montoya, arcangel de jesus', 'ramirez abadia, juan carlos', 'gonzalez benitez, olga patricia', 'patino fomeque, victor julio', 'duque botero, jorge alirio', 'echeverry herrera, hernando', 'alvarez tostado, jose', 'afghan, sher', 'cardenas guillen, osiel', 'caro quintero, miguel angel', 'chang, ping yun', 'gilboa, joseph', 'guzman loera, joaquin', 'hamieh, jamiel', 'higuera guerrero, ismael', 'khan, nasir ali', 'malherbe de leon, oscar', 'ramon magana, alcides', 'al-adl, sayf', 'al-walid, mahfouz ould', 'husayn, zayn al-abidin muhammad', 'al-iraqi, abd al-hadi', 'shihata, thirwat salah', 'ahmad, tariq anwar al-sayyid', 'abdullah, abdullah ahmed', 'ali, ahmed mohammed hamed', 'al-mughassil, ahmad ibrahim', 'al-nasser, abdelkarim hussein mohamed', 'al-yacoub, ibrahim salih mohammed', 'atwa, ali', 'el-hoorie, ali saed bin ali', 'fadhil, mustafa mohamed', 'ghailani, ahmed khalfan', 'izz-al-din, hasan', 'mohammed, fazul abdullah', 'mohammed, khalid shaikh', 'yasin, abdul rahman', 'agha, haji abdul manan', 'al-ahdal, mohammad hamdi mohammad sadiq', 'al-haq, amin', 'hamdan, salim ahmad salim', "al-sharif, sa'd abdullah hussein", 'bin marwan, bilal', 'bin muhammad, ayadi chafiq', 'darkazanli, mamoun', 'hijazi, riad', 'uthman, omar mahmoud', 'aweys, hassan dahir', 'mahmood, sultan bashir-ud-din', 'majeed, abdul', 'tufail, mohammed', 'boulghiti, boubekeur', 'al-libi, abd al-muhsin', 'aguilar amao, miguel', 'aguirre galindo, manuel', 'arellano felix, enedina', 'fregoso amezquita, maria antonieta', 'gil garcia, jose alejandro', 'hernandez pulido, maria elda', 'mijares trancoso, gilberto', 'moreno medina, luis ignacio', 'oropeza medrano, francisco javier', 'ramirez aguirre, sergio humberto', 'toledo carrejo, luis raul', 'abaunza martinez, javier', 'alberdi uranga, itziar', 'alcalde linares, angel', 'albisu iriarte, miguel', 'arzallus tapia, eusebio', 'elcoro ayastuy, paulo', 'figal arranz, antonio agustin', 'gogeascoechea arronategui, eneko', 'goiricelaya gonzalez, cristina', 'iparraguirre guenechea, maria soledad', 'morcillo torres, gracia', 'mugica goni, ainhoa', 'munoa ordozgoiti, alona', 'narvaez goni, juan jesus', 'olarra guridi, juan antonio', 'orbe sevillano, zigor', 'otegui unanue, mikel', 'perez aramburu, jon inaki', 'saez de eguilaz murguiondo, carlos', 'uranga artola, kemen', 'vila michelena, fermin', 'aouadi, mohamed ben belgacem', 'ben heni, lased', 'bouchoucha, mokhtar', 'es sayed, abdelkader mahmoud', 'essid, sami ben khemais', 'al-fawaz, khalid abd al-rahman hamd', 'al-masri, abu hamza', 'apaolaza sancho, ivan', 'berasategui escudero, ismael', 'gallastegui sodupe, lexuri', 'palacios alday, gorka', 'quintana zorrozua, asier', 'rubenach roig, juan luis', 'zubiaga bravo, manex', 'da costa, luis fernando', 'gonzalez quirarte, eduardo', 'ibrahim, haji', 'knowles, samuel', 'tuito, oded', 'zambada garcia, ismael', 'sison, jose maria', 'ben soltane, adel', 'ben attia, nabil  ...
# ['abu abbas', 'shaykh umar abd al rahman', 'dr. ayman al zawahiri', 'abboud abdul latif hassan al-zomor', 'abd al aziz awda', 'shaykh muhammad husayn fadlallah', 'nayif hawatma', 'mohammad shawqi islambouli', 'ahmad jabril', 'talal muhammad rashid naji', 'hasan nasrallah', 'subhi tufayli', 'sheik ahmed ismail yassin', 'mousa mohammed abu marzook', 'gilberto jose rodriguez orejuela', 'miguel angel rodriguez orejuela', 'ramadan abdallah', 'julio cesar nasser david', 'carlos alberto nasser arana', 'claudia patricia nasser arana', 'jorge nasser arana', 'usama bin muhammad bin awad bin ladin', 'abu hafs al-masri', "rifa'i ahmad taha musa", 'mohammed omar', 'ivan urdinola grajales', 'julio fabio urdinola grajales', 'lorena henao montoya', 'jose de jesus amezcua contreras', 'luis ignacio amezcua contreras', 'ramon eduardo arellano felix', 'rafael caro quintero', 'vicente carrillo fuentes', 'chi fu chang', 'noel timothy heath', 'oluwole a. ogungbuyi', 'abeni o. ogungbuyi', 'hsueh kang wei', 'benjamin alberto arellano felix', 'arcangel de jesus henao montoya', 'juan carlos ramirez abadia', 'olga patricia gonzalez benitez', 'victor julio patino fomeque', 'jorge alirio duque botero', 'hernando echeverry herrera', 'jose alvarez tostado', 'sher afghan', 'osiel cardenas guillen', 'miguel angel caro quintero', 'ping yun chang', 'joseph gilboa', 'joaquin guzman loera', 'jamiel hamieh', 'ismael higuera guerrero', 'nasir ali khan', 'oscar malherbe de leon', 'alcides ramon magana', 'sayf al-adl', 'mahfouz ould al-walid', 'zayn al-abidin muhammad husayn', 'abd al-hadi al-iraqi', 'thirwat salah shihata', 'tariq anwar al-sayyid ahmad', 'abdullah ahmed abdullah', 'ahmed mohammed hamed ali', 'ahmad ibrahim al-mughassil', 'abdelkarim hussein mohamed al-nasser', 'ibrahim salih mohammed al-yacoub', 'ali atwa', 'ali saed bin ali el-hoorie', 'mustafa mohamed fadhil', 'ahmed khalfan ghailani', 'hasan izz-al-din', 'fazul abdullah mohammed', 'khalid shaikh mohammed', 'abdul rahman yasin', 'haji abdul manan agha', 'mohammad hamdi mohammad sadiq al-ahdal', 'amin al-haq', 'salim ahmad salim hamdan', "sa'd abdullah hussein al-sharif", 'bilal bin marwan', 'ayadi chafiq bin muhammad', 'mamoun darkazanli', 'riad hijazi', 'omar mahmoud uthman', 'hassan dahir aweys', 'sultan bashir-ud-din mahmood', 'abdul majeed', 'mohammed tufail', 'boubekeur boulghiti', 'abd al-muhsin al-libi', 'miguel aguilar amao', 'manuel aguirre galindo', 'enedina arellano felix', 'maria antonieta fregoso amezquita', 'jose alejandro gil garcia', 'maria elda hernandez pulido', 'gilberto mijares trancoso', 'luis ignacio moreno medina', 'francisco javier oropeza medrano', 'sergio humberto ramirez aguirre', 'luis raul toledo carrejo', 'javier abaunza martinez', 'itziar alberdi uranga', 'angel alcalde linares', 'miguel albisu iriarte', 'eusebio arzallus tapia', 'paulo elcoro ayastuy', 'antonio agustin figal arranz', 'eneko gogeascoechea arronategui', 'cristina goiricelaya gonzalez', 'maria soledad iparraguirre guenechea', 'gracia morcillo torres', 'ainhoa mugica goni', 'alona munoa ordozgoiti', 'juan jesus narvaez goni', 'juan antonio olarra guridi', 'zigor orbe sevillano', 'mikel otegui unanue', 'jon inaki perez aramburu', 'carlos saez de eguilaz murguiondo', 'kemen uranga artola', 'fermin vila michelena', 'mohamed ben belgacem aouadi', 'lased ben heni', 'mokhtar bouchoucha', 'abdelkader mahmoud es sayed', 'sami ben khemais essid', 'khalid abd al-rahman hamd al-fawaz', 'abu hamza al-masri', 'ivan apaolaza sancho', 'ismael berasategui escudero', 'lexuri gallastegui sodupe', 'gorka palacios alday', 'asier quintana zorrozua', 'juan luis rubenach roig', 'manex zubiaga bravo', 'luis fernando da costa', 'eduardo gonzalez quirarte', 'haji ibrahim', 'samuel knowles', 'oded tuito', 'ismael zambada garcia', 'jose maria sison', 'adel ben soltane', 'nabil ben mohamed ben ali ben attia', 'yassine chekkouri', 'riadh ben belkassem ben mohamed jelassi', 'mehdi kammoun', 'samir kishk', 'tarek ben habib ben al-toumi ...

# %%
# Reading the provided Test Data
Test_Data = pd.read_excel('ABCNY Performance Metrics.xlsx', sheet_name=[1])

# %%
# Filtering out the Individual Names
Individuals = Test_Data[1][Test_Data[1]['Entity Type'] == 'Individual'].reset_index()

# %%
# Displaying the DataFrame
pd.set_option('display.max_rows', None)
Individuals.head()
# Out:
#    index  Rec. No         Theme      Category  \
# 0    115      116  Combinations  Combinations
# 1    116      117  Combinations  Combinations
# 2    117      118  Combinations  Combinations
# 3    118      119  Combinations  Combinations
# 4    119      120  Combinations  Combinations
#
#                                          Subcategory Entity Type  \
# 0  All given name initials with space between eac...  Individual
# 1   1 special character removed and 2 words combined  Individual
# 2  1 special character added and 1 letter replace...  Individual
# 3  2 typos same word non adjacent and 1 letter re...  Individual
# 4           2 truncations and variation of 2 letters  Individual
#
#                                    List Name  \
# 0             ANDREY KONSTANTINOVICH LUGOVOY
# 1  MUHAMMAD ABD-AL-QADIR MUTNI ASSAF AL-RAWI
# 2      ABD EL KADER MAHMOUD MOHAMED EL SAYED
# 3                   ABUBAKAR MOHAMMED SHEKAU
# 4            AIMAN MUHAMMED RABI AL-ZAWAHIRI
#
#                            Original List Name  \
# 0             LUGOVOY, ANDREY KONSTANTINOVICH
# 1  AL-RAWI, MUHAMMAD ABD-AL-QADIR MUTNI ASSAF
# 2      EL SAYED, ABD EL KADER MAHMOUD MOHAMED
# 3                   SHEKAU, ABUBAKAR MOHAMMED
# 4            AL-ZAWAHIRI, AIMAN MUHAMMED RABI
#
#                             Name Variation  ACCUITY ID  # of TPs  Volume
# 0                    A.  K.  L U G O V O Y  AS00850517         1       7
# 1  MUHAMMAD ABDAL-QADIR MUTNIASSAF AL-RAWI  AS06223109         1      84
# 2    ABD-EL KADER MAHM0UD MOHAMED EL SAYED  AS00022081         1      37
# 3                 ABOBEKAR M#HAMMED SHEKAU  AS00728855         1      12
# 4            AIMA MUHAMMAD RAB AL-JAWAHIRI  AS00020027         0      14

# %%
for i in range(len(Individuals['Original List Name'])):
    Individuals['Original List Name'].iloc[i] = Individuals['Original List Name'][i].lower()
    Individuals['List Name'].iloc[i] = str(Individuals['List Name'][i]).lower()

# %%
Individuals.head()
# Out:
#    index  Rec. No         Theme      Category  \
# 0    115      116  Combinations  Combinations
# 1    116      117  Combinations  Combinations
# 2    117      118  Combinations  Combinations
# 3    118      119  Combinations  Combinations
# 4    119      120  Combinations  Combinations
#
#                                          Subcategory Entity Type  \
# 0  All given name initials with space between eac...  Individual
# 1   1 special character removed and 2 words combined  Individual
# 2  1 special character added and 1 letter replace...  Individual
# 3  2 typos same word non adjacent and 1 letter re...  Individual
# 4           2 truncations and variation of 2 letters  Individual
#
#                                    List Name  \
# 0             andrey konstantinovich lugovoy
# 1  muhammad abd-al-qadir mutni assaf al-rawi
# 2      abd el kader mahmoud mohamed el sayed
# 3                   abubakar mohammed shekau
# 4            aiman muhammed rabi al-zawahiri
#
#                            Original List Name  \
# 0             lugovoy, andrey konstantinovich
# 1  al-rawi, muhammad abd-al-qadir mutni assaf
# 2      el sayed, abd el kader mahmoud mohamed
# 3                   shekau, abubakar mohammed
# 4            al-zawahiri, aiman muhammed rabi
#
#                             Name Variation  ACCUITY ID  # of TPs  Volume
# 0                    A.  K.  L U G O V O Y  AS00850517         1       7
# 1  MUHAMMAD ABDAL-QADIR MUTNIASSAF AL-RAWI  AS06223109         1      84
# 2    ABD-EL KADER MAHM0UD MOHAMED EL SAYED  AS00022081         1      37
# 3                 ABOBEKAR M#HAMMED SHEKAU  AS00728855         1      12
# 4            AIMA MUHAMMAD RAB AL-JAWAHIRI  AS00020027         0      14

# %%
elements=[] # Stores a tuple with Record Number, Original List Name and List Name for Individuals that are part of the OFAC List
nonelements=[] # Stores a tuple with Record Number, Original List Name and List Name for Individuals that are NOT part of the OFAC List
for recordno,oln,ln in zip(Individuals['Rec. No'],Individuals['Original List Name'],Individuals['List Name']):
    if oln in OFAC_List or ln in OFAC_Name_Clean_List or oln in OFAC_Name_Clean_List or ln in OFAC_List:
        elements.append((recordno,oln,ln,max(OFAC_List.count(oln),OFAC_List.count(ln),OFAC_Name_Clean_List.count(oln),OFAC_Name_Clean_List.count(ln))))
    else:
        nonelements.append((recordno,oln,ln,max(OFAC_List.count(oln),OFAC_List.count(ln),OFAC_Name_Clean_List.count(oln),OFAC_Name_Clean_List.count(ln))))
print(len(elements)) # Individual names part of the OFAC List - 641
print(len(nonelements))
print(nonelements) # Individual names not present in the OFAC List - 106
# Out:
# 641
# 106
# [(118, 'el sayed, abd el kader mahmoud mohamed', 'abd el kader mahmoud mohamed el sayed', 0), (119, 'shekau, abubakar mohammed', 'abubakar mohammed shekau', 0), (120, 'al-zawahiri, aiman muhammed rabi', 'aiman muhammed rabi al-zawahiri', 0), (123, 'al-maaroufi, tarek ben habib ben al-toumi', 'tarek ben habib ben al-toumi al-maaroufi', 0), (133, 'delos reyes jr., feliciano semborio', 'feliciano semborio delos reyes jr.', 0), (139, 'hameem m. abdu al-waly abdu al-azeez', 'hameem m. abdu al-waly abdu al-azeez', 0), (150, 'juarez de la roca, roberto eliud', 'juarez de la roca, roberto eliud', 0), (151, 'juarez de la roca, roberto eliud', 'juarez de la roca, roberto eliud', 0), (167, 'xiao liu', 'xiao liu', 0), (249, 'wali mohammad, abdul jalil haqqani', 'abdul jalil haqqani wali mohammad', 0), (251, 'bader, mohammed maher yousef', 'mohammed maher yousef bader', 0), (253, 'el sayed, abd el kader mahmoud mohamed', 'abd el kader mahmoud mohamed el sayed', 0), (255, 'al ajmi, hajjaj bin fahd', 'hajjaj bin fahd al ajmi', 0), (257, 'xiao quishi', 'xiao quishi', 0), (304, 'al ajmi, hajjaj bin fahd', 'hajjaj bin fahd al ajmi', 0), (336, 'qadhafi, muammar mohammed abu minyar', 'muammar mohammed abu minyar qadhafi', 0), (341, 'al-maaroufi, tarek ben habib ben al-toumi', 'tarek ben habib ben al-toumi al-maaroufi', 0), (370, 'juarez de la roca, roberto eliud', 'juarez de la roca, roberto eliud', 0), (371, 'juarez de la roca, roberto eliud', 'juarez de la roca, roberto eliud', 0), (372, 'juarez de la roca, roberto eliud', 'juarez de la roca, roberto eliud', 0), (373, 'abd al-ghafur, sundus', 'sundus abd al-ghafur', 0), (375, 'lugovoi, andrei konstantinovich', 'andrei konstantinovich lugovoi', 0), (376, 'delos reyes jr., feliciano semborio', 'feliciano semborio delos reyes jr.', 0), (378, 'amir khan motaqi', 'amir khan motaqi', 0), (380, 'elyazgi, captain', 'captain elyazgi', 0), (429, 'noorzai, abdul basir', 'abdul basir noorzai', 0), (449, 'azzam, mansur fadlallah', 'mansur fadlallah azzam', 0), (450, 'mun, myong hak', 'myong hak mun', 0), (451, 'al-ghamdi, othman ahmed othman', 'othman ahmed othman al-ghamdi', 0), (456, 'se, pak han', 'pak han se', 0), (465, 'cue zao', 'cue zao', 0), (470, 'tareq abdulkhaleq abdullah salem', 'tareq abdulkhaleq abdullah salem', 0), (473, 'chen, hui-fen', 'hui-fen chen', 0), (487, 'abdul rahmam, muhammad jibril', 'muhammad jibril abdul rahmam', 0), (677, 'al-amdouni, mehrez ben mahmoud ben sassi', 'mehrez ben mahmoud ben sassi al-amdouni', 0), (681, 'raddad, riyad', 'riyad raddad', 0), (686, 'zhou wenfang', 'zhou wenfang', 0), (742, 'al-masli, abd-al-hamid', 'abd-al-hamid al-masli', 0), (745, 'chen, angela', 'angela chen', 0), (747, 'taganda, bosco', 'bosco taganda', 0), (750, 'chur abdulla xu', 'chur abdulla xu', 0), (760, 'rotenberg, roman', 'roman rotenberg', 0), (762, 'tak, tam wai', 'tam wai tak', 0), (763, 'tak, tam wai', 'tam wai tak', 0), (841, 'al-rawi, _x0003_adnan muhammad amin', 'adnan muhammad amin al-rawi', 0), (850, 'ki, kwang ho', 'kwang ho ki', 0), (860, 'al-maaroufi, tarek ben habib ben al-toumi', 'tarek ben habib ben al-toumi al-maaroufi', 0), (861, 'wu hai yun', 'wu hai yun', 0), (909, 'delos reyes jr., feliciano semborio', 'feliciano semborio delos reyes jr.', 0), (924, 'umarov, doku khamatovich', 'doku khamatovich umarov', 0), (925, 'kim, yong dae', 'yong dae kim', 0), (929, 'timchenko, gennady', 'gennady timchenko', 0), (931, 'umarov, doku khamatovich', 'doku khamatovich umarov', 0), (973, 'al-rawi, _x0003_adnan muhammad amin', 'adnan muhammad amin al-rawi', 0), (978, 'al-hamraoui, kamal ben maoeldi ben hassan', 'kamal ben maoeldi ben hassan al-hamraoui', 0), (983, 'noorzai, abdul basir', 'abdul basir noorzai', 0), (1023, 'el sayed, abd el kader mahmoud mohamed', 'abd el kader mahmoud mohamed el sayed', 0), (1024, 'noorzai, abdul basir', 'abdul basir noorzai', 0), (1027, 'jin cai gui', 'jin cai gui', 0), (1074, 'abdo kasim ali alsuwary', 'abdo kasim ali alsuwary', 0), (1086, 'al-drissi,  ...

# %%
# OFAC List Name -> Test Data Name

# shekau, abubakar -> SHEKAU, ABUBAKAR MOHAMMED
# es sayed, abdelkader mahmoud -> EL SAYED, ABD EL KADER MAHMOUD MOHAMED
# maaroufi, tarek ben habib ben al-toumishaqiri, xhezair --> AL-MAAROUFI, TAREK BEN HABIB BEN AL-TOUMI
# timchenko, gennady nikolayevich --> GENNADY TIMCHENKO
# Not present -> CUE ZAO
# rotenberg, roman borisovich -> ROTENBERG, ROMAN

if 'ROTENBERG, ROMAN'.lower() in df_individuals['OFAC_Name']:
    print(1)
else:
    print(0)
# As observed above 106 'Test Data names not found in the OFAC List' 
# are some variations with missing Middle Names, Missing letter or  Not At all present
# Out:
# 0

# %%
print(len(Individuals[Individuals['# of TPs'] == 0]))
print(len(Individuals[Individuals['# of TPs'] == 1]))
print(len(Individuals[Individuals['# of TPs'] >= 2]))
print(85+648+14) # Total
# Count of Individual Names with 0 number of True Positives in the Test data = 85
# Count of Individual Names with 1 True Positive in the Test data = 648
# Count of Individual Names with more tahn 1 True Positive in the Test data = 14
# Out:
# 85
# 648
# 14
# 747

# %%
# Adding two columns to Test_Data - # of TPs(Obtained), Volume(Obtained)
# Here, '# of TPs(Obtained)' indicates if the Original List Name or List Name actually exists in the OFAC List
#  1 - 'It Exists'
#  0 - 'It does NOT Exist'
# Volume(Obtained) - indicates the volume of hits for a particular Name Variation with Double Metaphone with Levenshtein
Individuals['# of TPs(Obtained)']=0
for i in elements:
    for k in range(len(Individuals['Rec. No'])):
        if i[0] == Individuals['Rec. No'][k]:
            Individuals['# of TPs(Obtained)'].iloc[k]=i[3]

# %%
print(len(Individuals[Individuals['# of TPs(Obtained)']>1]))
print(len(Individuals[Individuals['# of TPs(Obtained)'] == 1]))
print(len(Individuals[Individuals['# of TPs(Obtained)'] == 0]))
# Out:
# 0
# 641
# 106

# %%
# Converting all the Name Variations to string type
for i in range(len(Individuals['Name Variation'])):
    Individuals['Name Variation'].iloc[i] = str(Individuals['Name Variation'][i])

# %%
# Removed all the Digits from the Name Variation
remove_numbers(Individuals, 'Name Variation', 'Digits Removed')

# %%
Individuals.tail(5)
# Out:
#      index  Rec. No                                Theme  \
# 742   2581     2582                                  IDs
# 743   2582     2583                                  IDs
# 744   2583     2584  Names where name parts are Modified
# 745   2584     2585  Names where name parts are Modified
# 746   2585     2586  Names where name parts are Modified
#
#                      Category            Subcategory Entity Type  \
# 742  Digital Currency Address  With space and period  Individual
# 743  Digital Currency Address  With space and period  Individual
# 744       Combined Name Split    Combined Name Split  Individual
# 745       Combined Name Split    Combined Name Split  Individual
# 746       Combined Name Split    Combined Name Split  Individual
#
#                         List Name            Original List Name  \
# 742               potekhin, danil               potekhin, danil
# 743  andreyev, anton nikolaeyvich  andreyev, anton nikolaeyvich
# 744         santos, ahmad (ahmed)         santos, ahmad (ahmed)
# 745         santos, ahmad (ahmed)         santos, ahmad (ahmed)
# 746         santos, ahmad (ahmed)         santos, ahmad (ahmed)
#
#            Name Variation  ACCUITY ID  # of TPs  Volume  # of TPs(Obtained)  \
# 742   .xFcCcEebfbeADEbe B  AS06306302         2      12                   1
# 743  X. ACCCDCEFEBFBDFCFC  AS06305898         1       7                   1
# 744         SANTOS, Ahmad  AS00229428         1      16                   1
# 745   SANTOS, Ahmad Ahmed  AS00229428         1      42                   1
# 746         Santos, Ahmed  AS00229428         1      18                   1
#
#                 Digits Removed
# 742  0736741522075538233798891
# 743   085765056884496506291353
# 744
# 745
# 746

# %%
# For comparing the Name Variation, we would change name order to First Middle Last and change to lower case
Individuals['Name Variation First Last']=''
for i in range(len(Individuals['Name Variation'])):
    Individuals['Name Variation First Last'].iloc[i] = first_name_before_last_name(Individuals['Name Variation'][i])

# %%
# Removing the punctuations in the Name
column_cleaning(Individuals, 'Name Variation First Last', 'Name Variation Clean')

# %%
Individuals.head(10)
# Out:
#    index  Rec. No         Theme      Category  \
# 0    115      116  Combinations  Combinations
# 1    116      117  Combinations  Combinations
# 2    117      118  Combinations  Combinations
# 3    118      119  Combinations  Combinations
# 4    119      120  Combinations  Combinations
# 5    120      121  Combinations  Combinations
# 6    121      122  Combinations  Combinations
# 7    122      123  Combinations  Combinations
# 8    123      124  Combinations  Combinations
# 9    124      125  Combinations  Combinations
#
#                                          Subcategory Entity Type  \
# 0  All given name initials with space between eac...  Individual
# 1   1 special character removed and 2 words combined  Individual
# 2  1 special character added and 1 letter replace...  Individual
# 3  2 typos same word non adjacent and 1 letter re...  Individual
# 4           2 truncations and variation of 2 letters  Individual
# 5         Truncation at the beginning, 1 compression  Individual
# 6  Removal of special characters, compression, an...  Individual
# 7                    Compression and Name Part added  Individual
# 8  First / middle name swapped with 1 character r...  Individual
# 9                           Typo and Name Part added  Individual
#
#                                            List Name  \
# 0                     andrey konstantinovich lugovoy
# 1          muhammad abd-al-qadir mutni assaf al-rawi
# 2              abd el kader mahmoud mohamed el sayed
# 3                           abubakar mohammed shekau
# 4                    aiman muhammed rabi al-zawahiri
# 5                      jairo humberto lopera barbosa
# 6  muhammad hadi 'abd-al-rahman fayhan sharban al...
# 7           tarek ben habib ben al-toumi al-maaroufi
# 8                aleksey aleksandrovich kostrubitsky
# 9                       aleksey aleksandrovich dikiy
#
#                                   Original List Name  \
# 0                    lugovoy, andrey konstantinovich
# 1         al-rawi, muhammad abd-al-qadir mutni assaf
# 2             el sayed, abd el kader mahmoud mohamed
# 3                          shekau, abubakar mohammed
# 4                   al-zawahiri, aiman muhammed rabi
# 5                     lopera barbosa, jairo humberto
# 6  al-_x0003_anzi, muhammad hadi _x0003_abd-al-ra...
# 7          al-maaroufi, tarek ben habib ben al-toumi
# 8               kostrubitsky, aleksey aleksandrovich
# 9                      dikiy, aleksey aleksandrovich
#
#                                     Name Variation  ACCUITY ID  # of TPs  \
# 0                            A.  K.  L U G O V O Y  AS00850517         1
# 1          MUHAMMAD ABDAL-QADIR MUTNIASSAF AL-RAWI  AS06223109         1
# 2             ABD-EL KADER MAHMUD MOHAMED EL SAYED  AS00022081         1
# 3                         ABOBEKAR M#HAMMED SHEKAU  AS00728855         1
# 4                    AIMA MUHAMMAD RAB AL-JAWAHIRI  AS00020027         0
# 5                      AIRO HUMBERTOLOPERA BARBOSA  AS00178815         1
# 6  AL MUHAMMADHADIABDALRAHMANFAYHAN SHARBAN ALANZI  AS00095739         1
# 7       AL TAREKBEN HABIB BEN AL-TOUMI AL-MAAROUFI  AS00033155         1
# 8               ALEKSANDROVICH ALEKSEY KOSTRUBITKY  AS00258040         1
# 9            ALEKSEY VLADAMIR ALEKSANDROVICH DIKEY  AS00258045         1
#
#    Volume  # of TPs(Obtained) Digits Removed  \
# 0       7                   1
# 1      84                   1
# 2      37                   0              0
# 3      12                   0
# 4      14                   0
# 5      15                   1
# 6       8                   1
# 7      11                   0
# 8       8                   1
# 9       7                   1
#
#                          Name Variation First Last  \
# 0                            a.  k.  l u g o v o y
# 1          muhammad abdal-qadir mutniassaf al-rawi
# 2             abd-el kader mahmud mohamed el sayed
# 3                         abobekar m#hammed shekau
# 4                    aima muhammad rab al-jawahiri
# 5                      airo humbertolopera barbosa
# 6  al muhammadhadiabdalrahmanfayhan sharban alanzi
# 7       al tarekben habib ben al-toumi al-maaroufi
# 8               aleksandrovich aleksey kostrubitky
# 9            aleksey vladamir aleksandrovich dikey
#
#                               Name Variation Clean
# 0                              a  k  l u g o v o y
# 1            muhammad abdalqadir mutniassaf alrawi
# 2              abdel kader mahmud mohamed el sayed
# 3                          abobekar mhammed shekau
# 4                     aima muhammad rab aljawahiri
# 5                      airo humbertolopera barbosa
# 6  al muhammadhadiabdalrahmanfayhan sharban alanzi
# 7         al tarekben habib ben altoumi almaaroufi
# 8               aleksandrovich aleksey kostrubitky
# 9            aleksey vladamir aleksandrovich dikey

# %%
def doublemetaphone_with_leven_word_by_word(OFAC_list_Individuals, Test_data_sample, doublemataphone_Cutoff_List, Levenshtein_Cutoff):
#     dict={}
    Individuals['VOHs(DoubleMetaphone)'] = 0
    Individuals['TP predicted by doublemetaphone'] = 0
    for cut_off in doublemataphone_Cutoff_List:
        print('cut_off:',cut_off)
        Scored_dataframe=pd.DataFrame(columns=['Name_Variation_compared','OFAC_Name','Subcategory','# of TPs','Volume','# of TPs(Obtained)']) 
        for i in range(len(Test_data_sample)):
            print(' i:',i)
            count = 0
            TP = 0
            for j in range(len(OFAC_list_Individuals)):

                Ofac_name = OFAC_list_Individuals['OFAC_Name'][j]
                Ofac_name_clean = OFAC_list_Individuals['OFAC_Name_Clean'][j]
                Name_Variation = Test_data_sample['Name Variation Clean'][i]
                Orignal_list_name = Test_data_sample['Original List Name'][i]
                List_name = Test_data_sample['List Name'][i]
                Transformation = Test_data_sample['Subcategory'][i]
                No_of_TPs = Test_data_sample['# of TPs'][i]
                Volume = Test_data_sample['Volume'][i]
                No_of_TPs_obtained = Test_data_sample['# of TPs(Obtained)'][i]
                
                
            
                if doublemetaphone(Ofac_name_clean) == doublemetaphone(Name_Variation):
                    count+=1
                    if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                        TP+= 1
#                     if Orignal_Name_OFAC == Orignal_Name_Test:
#                         doublemetaphone_score = 1
                    Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
                else:
                    original_list = Ofac_name_clean.split()
                    test_list = Name_Variation.split()
                    n_matches = 0
                    if ''.join(original_list).replace(' ','') == ''.join(test_list).replace(' ',''):
                        count+=1
                        if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                            TP+= 1
                        Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
                    else:
                        for n in range(len(original_list)):
                            for m in range(len(test_list)):
                                if doublemetaphone(original_list[n])  == doublemetaphone(test_list[m]):
                                    n_matches += 1 
                        if n_matches / len(original_list) >= cut_off:
                            count+=1
                            if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                                TP+= 1
                            Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
                        else:
                             if enchant.utils.levenshtein(Ofac_name_clean,Name_Variation) <= Levenshtein_Cutoff:
                                count+=1
                                if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                                    TP+= 1
                                Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
            Individuals['VOHs(DoubleMetaphone)'].iloc[i] = count  
            Individuals['TP predicted by doublemetaphone'].iloc[i] = TP
#         dict[cut_off] = Scored_dataframe
    return Scored_dataframe

# %%
df = doublemetaphone_with_leven_word_by_word(df_individuals, Individuals, [0.5], 3)
# Out:
# cut_off: 0.5
#  i: 0
#  i: 1
#  i: 2
#  i: 3
#  i: 4
#  i: 5
#  i: 6
#  i: 7
#  i: 8
#  i: 9
#  i: 10
#  i: 11
#  i: 12
#  i: 13
#  i: 14
#  i: 15
#  i: 16
#  i: 17
#  i: 18
#  i: 19
#  i: 20
#  i: 21
#  i: 22
#  i: 23
#  i: 24
#  i: 25
#  i: 26
#  i: 27
#  i: 28
#  i: 29
#  i: 30
#  i: 31
#  i: 32
#  i: 33
#  i: 34
#  i: 35
#  i: 36
#  i: 37
#  i: 38
#  i: 39
#  i: 40
#  i: 41
#  i: 42
#  i: 43
#  i: 44
#  i: 45
#  i: 46
#  i: 47
#  i: 48
#  i: 49
#  i: 50
#  i: 51
#  i: 52
#  i: 53
#  i: 54
#  i: 55
#  i: 56
#  i: 57
#  i: 58
#  i: 59
#  i: 60
#  i: 61
#  i: 62
#  i: 63
#  i: 64
#  i: 65
#  i: 66
#  i: 67
#  i: 68
#  i: 69
#  i: 70
#  i: 71
#  i: 72
#  i: 73
#  i: 74
#  i: 75
#  i: 76
#  i: 77
#  i: 78
#  i: 79
#  i: 80
#  i: 81
#  i: 82
#  i: 83
#  i: 84
#  i: 85
#  i: 86
#  i: 87
#  i: 88
#  i: 89
#  i: 90
#  i: 91
#  i: 92
#  i: 93
#  i: 94
#  i: 95
#  i: 96
#  i: 97
#  i: 98
#  i: 99
#  i: 100
#  i: 101
#  i: 102
#  i: 103
#  i: 104
#  i: 105
#  i: 106
#  i: 107
#  i: 108
#  i: 109
#  i: 110
#  i: 111
#  i: 112
#  i: 113
#  i: 114
#  i: 115
#  i: 116
#  i: 117
#  i: 118
#  i: 119
#  i: 120
#  i: 121
#  i: 122
#  i: 123
#  i: 124
#  i: 125
#  i: 126
#  i: 127
#  i: 128
#  i: 129
#  i: 130
#  i: 131
#  i: 132
#  i: 133
#  i: 134
#  i: 135
#  i: 136
#  i: 137
#  i: 138
#  i: 139
#  i: 140
#  i: 141
#  i: 142
#  i: 143
#  i: 144
#  i: 145
#  i: 146
#  i: 147
#  i: 148
#  i: 149
#  i: 150
#  i: 151
#  i: 152
#  i: 153
#  i: 154
#  i: 155
#  i: 156
#  i: 157
#  i: 158
#  i: 159
#  i: 160
#  i: 161
#  i: 162
#  i: 163
#  i: 164
#  i: 165
#  i: 166
#  i: 167
#  i: 168
#  i: 169
#  i: 170
#  i: 171
#  i: 172
#  i: 173
#  i: 174
#  i: 175
#  i: 176
#  i: 177
#  i: 178
#  i: 179
#  i: 180
#  i: 181
#  i: 182
#  i: 183
#  i: 184
#  i: 185
#  i: 186
#  i: 187
#  i: 188
#  i: 189
#  i: 190
#  i: 191
#  i: 192
#  i: 193
#  i: 194
#  i: 195
#  i: 196
#  i: 197
#  i: 198
#  i: 199
#  i: 200
#  i: 201
#  i: 202
#  i: 203
#  i: 204
#  i: 205
#  i: 206
#  i: 207
#  i: 208
#  i: 209
#  i: 210
#  i: 211
#  i: 212
#  i: 213
#  i: 214
#  i: 215
#  i: 216
#  i: 217
#  i: 218
#  i: 219
#  i: 220
#  i: 221
#  i: 222
#  i: 223
#  i: 224
#  i: 225
#  i: 226
#  i: 227
#  i: 228
#  i: 229
#  i: 230
#  i: 231
#  i: 232
#  i: 233
#  i: 234
#  i: 235
#  i: 236
#  i: 237
#  i: 238
#  i: 239
#  i: 240
#  i: 241
#  i: 242
#  i: 243
#  i: 244
#  i: 245
#  i: 246
#  i: 247
#  i: 248
#  i: 249
#  i: 250
#  i: 251
#  i: 252
#  i: 253
#  i: 254
#  i: 255
#  i: 256
#  i: 257
#  i: 258
#  i: 259
#  i: 260
#  i: 261
#  i: 262
#  i: 263
#  i: 264
#  i: 265
#  i: 266
#  i: 267
#  i: 268
#  i: 269
#  i: 270
#  i: 271
#  i: 272
#  i: 273
#  i: 274
#  i: 275
#  i: 276
#  i: 277
#  i: 278
#  i: 279
#  i: 280
#  i: 281
#  i: 282
#  i: 283
#  i: 284
#  i: 285
#  i: 286
#  i: 287
#  i: 288
#  i: 289
#  i: 290
#  i: 291
#  i: 292
#  i: 293
#  i: 294
#  i: 295
#  i: 296
#  i: 297
#  i: 298
#  i: 299
#  i: 300
#  i: 301
#  i: 302
#  i: 303
#  i: 304
#  i: 305
#  i: 306
#  i: 307
#  i: 308
#  i: 309
#  i: 310
#  i: 311
#  i: 312
#  i: 313
#  i: 314
#  i: 315
#  i: 316
#  i: 317
#  i: 318
#  i: 319
#  i: 320
#  i: 321
#  i: 322
#  i: 323
#  i: 324
#  i: 325
#  i: 326
#  i: 327
#  i: 328
#  i: 329
#  i: 330
#  i: 331
#  i: 332
#  i: 333
#  i: 334
#  i: 335
#  i: 336
#  i: 337
#  i: 338
#  i: 339
#  i: 340
#  i: 341
#  i: 342
#  i: 343
#  i: 344
#  i: 345
#  i: 346
#  i: 347
#  i: 348
#  i: 349
#  i: 350
#  i: 351
#  i: 352
#  i: 353
#  i: 354
#  i: 355
#  i: 356
#  i: 357
#  i: 358
#  i: 359
#  i: 360
#  i: 361
#  i: 362
#  i: 363
#  i: 364
#  i: 365
#  i: 366
#  i: 367
#  i: 368
#  i: 369
#  i: 370
#  i: 371
#  i: 372
#  i: 373
#  i: 374
#  i: 375
#  i: 376
#  i: 377
#  i: 378
#  i: 379
#  i: 380
#  i: 381
#  i: 382
#  i: 383
#  i: 384
#  i: 385
#  i: 386
#  i: 387
#  i: 388
#  i: 389
#  i: 390
#  i: 391
#  i: 392
#  i: 393
#  i: 394
#  i: 395
#  i: 396
#  i: 397
#  i: 398
#  i: 399
#  i: 400
#  i: 401
#  i: 402
#  i: 403
#  i: 404
#  i: 405
#  i: 406
#  i: 407
#  i: 408
#  i: 409
#  i: 410
#  i: 411
#  i: 412
#  i: 413
#  i: 414
#  i: 415
#  i: 416
#  i: 417
#  i: 418
#  i: 419
#  i: 420
#  i: 421
#  i: 422
#  i: 423
#  i: 424
#  i: 425
#  i: 426
#  i: 427
#  i: 428
#  i: 429
#  i: 430
#  i: 431
#  i: 432
#  i: 433
#  i: 434
#  i: 435
#  i: 436
#  i: 437
#  i: 438
#  i: 439
#  i: 440
#  i: 441
#  i: 442
#  i: 443
#  i: 444
#  i: 445
#  i: 446
#  i: 447
#  i: 448
#  i: 449
#  i: 450
#  i: 451
#  i: 452
#  i: 453
#  i: 454
#  i: 455
#  i: 456
#  i: 457
#  i: 458
#  i: 459
#  i: 460
#  i: 461
#  i: 462
#  i: 463
#  i: 464
#  i: 465
#  i: 466
#  i: 467
#  i: 468
#  i: 469
#  i: 470
#  i: 471
#  i: 472
#  i: 473
#  i: 474
#  i: 475
#  i: 476
#  i: 477
#  i: 478
#  i: 479
#  i: 480
#  i: 481
#  i: 482
#  i: 483
#  i: 484
#  i: 485
#  i: 486
#  i: 487
#  i: 488
#  i: 489
#  i: 490
#  i: 491
#  i: 492
#  i: 493
#  i: 494
#  i: 495
#  i: 496
#  i: 497
#  i: 498
#  i: 499
#  i: 500
#  i: 501
#  i: 502
#  i: 503
#  i: 504
#  i: 505
#  i: 506
#  i: 507
#  i: 508
#  i: 509
#  i: 510
#  i: 511
#  i: 512
#  i: 513
#  i: 514
#  i: 515
#  i: 516
#  i: 517
#  i: 518
#  i: 519
#  i: 520
#  i: 521
#  i: 522
#  i: 523
#  i: 524
#  i: 525
#  i: 526
#  i: 527
#  i: 528
#  i: 529
#  i: 530
#  i: 531
#  i: 532
#  i: 533
#  i: 534
#  i: 535
#  i: 536
#  i: 537
#  i: 538
#  i: 539
#  i: 540
#  i: 541
#  i: 542
#  i: 543
#  i: 544
#  i: 545
#  i: 546
#  i: 547
#  i: 548
#  i: 549
#  i: 550
#  i: 551
#  i: 552
#  i: 553
#  i: 554
#  i: 555
#  i: 556
#  i: 557
#  i: 558
#  i: 559
#  i: 560
#  i: 561
#  i: 562
#  i: 563
#  i: 564
#  i: 565
#  i: 566
#  i: 567
#  i: 568
#  i: 569
#  i: 570
#  i: 571
#  i: 572
#  i: 573
#  i: 574
#  i: 575
#  i: 576
#  i: 577
#  i: 578
#  i: 579
#  i: 580
#  i: 581
#  i: 582
#  i: 583
#  i: 584
#  i: 585
#  i: 586
#  i: 587
#  i: 588
#  i: 589
#  i: 590
#  i: 591
#  i: 592
#  i: 593
#  i: 594
#  i: 595
#  i: 596
#  i: 597
#  i: 598
#  i: 599
#  i: 600
#  i: 601
#  i: 602
#  i: 603
#  i: 604
#  i: 605
#  i: 606
#  i: 607
#  i: 608
#  i: 609
#  i: 610
#  i: 611
#  i: 612
#  i: 613
#  i: 614
#  i: 615
#  i: 616
#  i: 617
#  i: 618
#  i: 619
#  i: 620
#  i: 621
#  i: 622
#  i: 623
#  i: 624
#  i: 625
#  i: 626
#  i: 627
#  i: 628
#  i: 629
#  i: 630
#  i: 631
#  i: 632
#  i: 633
#  i: 634
#  i: 635
#  i: 636
#  i: 637
#  i: 638
#  i: 639
#  i: 640
#  i: 641
#  i: 642
#  i: 643
#  i: 644
#  i: 645
#  i: 646
#  i: 647
#  i: 648
#  i: 649
#  i: 650
#  i: 651
#  i: 652
#  i: 653
#  i: 654
#  i: 655
#  i: 656
#  i: 657
#  i: 658
#  i: 659
#  i: 660
#  i: 661
#  i: 662
#  i: 663
#  i: 664
#  i: 665
#  i: 666
#  i: 667
#  i: 668
#  i: 669
#  i: 670
#  i: 671
#  i: 672
#  i: 673
#  i: 674
#  i: 675
#  i: 676
#  i: 677
#  i: 678
#  i: 679
#  i: 680
#  i: 681
#  i: 682
#  i: 683
#  i: 684
#  i: 685
#  i: 686
#  i: 687
#  i: 688
#  i: 689
#  i: 690
#  i: 691
#  i: 692
#  i: 693
#  i: 694
#  i: 695
#  i: 696
#  i: 697
#  i: 698
#  i: 699
#  i: 700
#  i: 701
#  i: 702
#  i: 703
#  i: 704
#  i: 705
#  i: 706
#  i: 707
#  i: 708
#  i: 709
#  i: 710
#  i: 711
#  i: 712
#  i: 713
#  i: 714
#  i: 715
#  i: 716
#  i: 717
#  i: 718
#  i: 719
#  i: 720
#  i: 721
#  i: 722
#  i: 723
#  i: 724
#  i: 725
#  i: 726
#  i: 727
#  i: 728
#  i: 729
#  i: 730
#  i: 731
#  i: 732
#  i: 733
#  i: 734
#  i: 735
#  i: 736
#  i: 737
#  i: 738
#  i: 739
#  i: 740
#  i: 741
#  i: 742
#  i: 743
#  i: 744
#  i: 745
#  i: 746

# %%
print(Individuals['VOHs(DoubleMetaphone)'].sum()) # VOHs: 24284
print(Individuals['Volume'].sum())
print(Individuals.head())
Individuals['TP predicted by doublemetaphone'].sum() # TPs catured by DoubleMetaphone: 417
TP_percent = Individuals['TP predicted by doublemetaphone'].sum()/Individuals['# of TPs(Obtained)'].sum()
TP_percent # TP%(Double Metaphone): 65.05%
# Out:
# 24284
# 11807
#    index  Rec. No         Theme      Category  \
# 0    115      116  Combinations  Combinations
# 1    116      117  Combinations  Combinations
# 2    117      118  Combinations  Combinations
# 3    118      119  Combinations  Combinations
# 4    119      120  Combinations  Combinations
#
#                                          Subcategory Entity Type  \
# 0  All given name initials with space between eac...  Individual
# 1   1 special character removed and 2 words combined  Individual
# 2  1 special character added and 1 letter replace...  Individual
# 3  2 typos same word non adjacent and 1 letter re...  Individual
# 4           2 truncations and variation of 2 letters  Individual
#
#                                    List Name  \
# 0             andrey konstantinovich lugovoy
# 1  muhammad abd-al-qadir mutni assaf al-rawi
# 2      abd el kader mahmoud mohamed el sayed
# 3                   abubakar mohammed shekau
# 4            aiman muhammed rabi al-zawahiri
#
#                            Original List Name  \
# 0             lugovoy, andrey konstantinovich
# 1  al-rawi, muhammad abd-al-qadir mutni assaf
# 2      el sayed, abd el kader mahmoud mohamed
# 3                   shekau, abubakar mohammed
# 4            al-zawahiri, aiman muhammed rabi
#
#                             Name Variation  ACCUITY ID  # of TPs  Volume  \
# 0                    A.  K.  L U G O V O Y  AS00850517         1       7
# 1  MUHAMMAD ABDAL-QADIR MUTNIASSAF AL-RAWI  AS06223109         1      84
# 2     ABD-EL KADER MAHMUD MOHAMED EL SAYED  AS00022081         1      37
# 3                 ABOBEKAR M#HAMMED SHEKAU  AS00728855         1      12
# 4            AIMA MUHAMMAD RAB AL-JAWAHIRI  AS00020027         0      14
#
#    # of TPs(Obtained) Digits Removed                Name Variation First Last  \
# 0                   1                                   a.  k.  l u g o v o y
# 1                   1                 muhammad abdal-qadir mutniassaf al-rawi
# 2                   0              0     abd-el kader mahmud mohamed el sayed
# 3                   0                                abobekar m#hammed shekau
# 4                   0                           aima muhammad rab al-jawahiri
#
#                     Name Variation Clean  VOHs(DoubleMetaphone)  \
# 0                    a  k  l u g o v o y                    103
# 1  muhammad abdalqadir mutniassaf alrawi                    101
# 2    abdel kader mahmud mohamed el sayed                    320
# 3                abobekar mhammed shekau                     18
# 4           aima muhammad rab aljawahiri                    101
#
#    TP predicted by doublemetaphone
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# 0.6505460218408736

# %% [markdown]
# # Soundex(cutoff:0.5) with Levenshtein Distance(6)

# %%
def soundex_with_leven_word_by_word(OFAC_list_Individuals, Test_data_sample, doublemataphone_Cutoff_List, Levenshtein_Cutoff):

    Individuals['VOHs(Soundex)'] = 0
    Individuals['TP predicted by soundex'] = 0
    
    for cut_off in doublemataphone_Cutoff_List:
        print('cut_off:',cut_off)
        Scored_dataframe=pd.DataFrame(columns=['Name_Variation_compared','OFAC_Name','Subcategory','# of TPs','Volume','# of TPs(Obtained)']) 
        for i in range(len(Test_data_sample)):
            print(' i:',i)
            count = 0
            TP = 0
            for j in range(len(OFAC_list_Individuals)):

                Ofac_name = OFAC_list_Individuals['OFAC_Name'][j]
                Ofac_name_clean = OFAC_list_Individuals['OFAC_Name_Clean'][j]
                Name_Variation = Test_data_sample['Name Variation Clean'][i]
                Orignal_list_name = Test_data_sample['Original List Name'][i]
                List_name = Test_data_sample['List Name'][i]
                Transformation = Test_data_sample['Subcategory'][i]
                No_of_TPs = Test_data_sample['# of TPs'][i]
                Volume = Test_data_sample['Volume'][i]
                No_of_TPs_obtained = Test_data_sample['# of TPs(Obtained)'][i]
                
                
            
                if (jellyfish.soundex(Ofac_name_clean) == jellyfish.soundex(Name_Variation)):
                    count+=1
                    if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                        TP+= 1
#                     if Orignal_Name_OFAC == Orignal_Name_Test:
#                         doublemetaphone_score = 1
                    Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
                else:
                    original_list = Ofac_name_clean.split()
                    test_list = Name_Variation.split()
                    n_matches = 0
                    if ''.join(original_list).replace(' ','') == ''.join(test_list).replace(' ',''):
                        count+=1
                        if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                            TP+= 1
                        Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
                    else:
                        for n in range(len(original_list)):
                            for m in range(len(test_list)):
                                if jellyfish.soundex(original_list[n])  == jellyfish.soundex(test_list[m]):
                                    n_matches += 1 
                        if n_matches / len(original_list) >= cut_off:
                            count+=1
                            if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                                TP+= 1
                            Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
                        else:
                             if enchant.utils.levenshtein(Ofac_name_clean,Name_Variation) <= Levenshtein_Cutoff:
                                count+=1
                                if Ofac_name == Orignal_list_name or Ofac_name == List_name or Ofac_name_clean == Orignal_list_name or Ofac_name_clean == List_name:
                                    TP+= 1
                                Scored_dataframe.loc[len(Scored_dataframe.index)]=[Ofac_name, Name_Variation, Transformation, No_of_TPs, Volume, No_of_TPs_obtained]
            Individuals['VOHs(Soundex)'].iloc[i] = count  
            Individuals['TP predicted by soundex'].iloc[i] = TP

    return Scored_dataframe

# %%
df2 = soundex_with_leven_word_by_word(df_individuals, Individuals, [0.5], 6)
# Out:
# cut_off: 0.5
#  i: 0
#  i: 1
#  i: 2
#  i: 3
#  i: 4
#  i: 5
#  i: 6
#  i: 7
#  i: 8
#  i: 9
#  i: 10
#  i: 11
#  i: 12
#  i: 13
#  i: 14
#  i: 15
#  i: 16
#  i: 17
#  i: 18
#  i: 19
#  i: 20
#  i: 21
#  i: 22
#  i: 23
#  i: 24
#  i: 25
#  i: 26
#  i: 27
#  i: 28
#  i: 29
#  i: 30
#  i: 31
#  i: 32
#  i: 33
#  i: 34
#  i: 35
#  i: 36
#  i: 37
#  i: 38
#  i: 39
#  i: 40
#  i: 41
#  i: 42
#  i: 43
#  i: 44
#  i: 45
#  i: 46
#  i: 47
#  i: 48
#  i: 49
#  i: 50
#  i: 51
#  i: 52
#  i: 53
#  i: 54
#  i: 55
#  i: 56
#  i: 57
#  i: 58
#  i: 59
#  i: 60
#  i: 61
#  i: 62
#  i: 63
#  i: 64
#  i: 65
#  i: 66
#  i: 67
#  i: 68
#  i: 69
#  i: 70
#  i: 71
#  i: 72
#  i: 73
#  i: 74
#  i: 75
#  i: 76
#  i: 77
#  i: 78
#  i: 79
#  i: 80
#  i: 81
#  i: 82
#  i: 83
#  i: 84
#  i: 85
#  i: 86
#  i: 87
#  i: 88
#  i: 89
#  i: 90
#  i: 91
#  i: 92
#  i: 93
#  i: 94
#  i: 95
#  i: 96
#  i: 97
#  i: 98
#  i: 99
#  i: 100
#  i: 101
#  i: 102
#  i: 103
#  i: 104
#  i: 105
#  i: 106
#  i: 107
#  i: 108
#  i: 109
#  i: 110
#  i: 111
#  i: 112
#  i: 113
#  i: 114
#  i: 115
#  i: 116
#  i: 117
#  i: 118
#  i: 119
#  i: 120
#  i: 121
#  i: 122
#  i: 123
#  i: 124
#  i: 125
#  i: 126
#  i: 127
#  i: 128
#  i: 129
#  i: 130
#  i: 131
#  i: 132
#  i: 133
#  i: 134
#  i: 135
#  i: 136
#  i: 137
#  i: 138
#  i: 139
#  i: 140
#  i: 141
#  i: 142
#  i: 143
#  i: 144
#  i: 145
#  i: 146
#  i: 147
#  i: 148
#  i: 149
#  i: 150
#  i: 151
#  i: 152
#  i: 153
#  i: 154
#  i: 155
#  i: 156
#  i: 157
#  i: 158
#  i: 159
#  i: 160
#  i: 161
#  i: 162
#  i: 163
#  i: 164
#  i: 165
#  i: 166
#  i: 167
#  i: 168
#  i: 169
#  i: 170
#  i: 171
#  i: 172
#  i: 173
#  i: 174
#  i: 175
#  i: 176
#  i: 177
#  i: 178
#  i: 179
#  i: 180
#  i: 181
#  i: 182
#  i: 183
#  i: 184
#  i: 185
#  i: 186
#  i: 187
#  i: 188
#  i: 189
#  i: 190
#  i: 191
#  i: 192
#  i: 193
#  i: 194
#  i: 195
#  i: 196
#  i: 197
#  i: 198
#  i: 199
#  i: 200
#  i: 201
#  i: 202
#  i: 203
#  i: 204
#  i: 205
#  i: 206
#  i: 207
#  i: 208
#  i: 209
#  i: 210
#  i: 211
#  i: 212
#  i: 213
#  i: 214
#  i: 215
#  i: 216
#  i: 217
#  i: 218
#  i: 219
#  i: 220
#  i: 221
#  i: 222
#  i: 223
#  i: 224
#  i: 225
#  i: 226
#  i: 227
#  i: 228
#  i: 229
#  i: 230
#  i: 231
#  i: 232
#  i: 233
#  i: 234
#  i: 235
#  i: 236
#  i: 237
#  i: 238
#  i: 239
#  i: 240
#  i: 241
#  i: 242
#  i: 243
#  i: 244
#  i: 245
#  i: 246
#  i: 247
#  i: 248
#  i: 249
#  i: 250
#  i: 251
#  i: 252
#  i: 253
#  i: 254
#  i: 255
#  i: 256
#  i: 257
#  i: 258
#  i: 259
#  i: 260
#  i: 261
#  i: 262
#  i: 263
#  i: 264
#  i: 265
#  i: 266
#  i: 267
#  i: 268
#  i: 269
#  i: 270
#  i: 271
#  i: 272
#  i: 273
#  i: 274
#  i: 275
#  i: 276
#  i: 277
#  i: 278
#  i: 279
#  i: 280
#  i: 281
#  i: 282
#  i: 283
#  i: 284
#  i: 285
#  i: 286
#  i: 287
#  i: 288
#  i: 289
#  i: 290
#  i: 291
#  i: 292
#  i: 293
#  i: 294
#  i: 295
#  i: 296
#  i: 297
#  i: 298
#  i: 299
#  i: 300
#  i: 301
#  i: 302
#  i: 303
#  i: 304
#  i: 305
#  i: 306
#  i: 307
#  i: 308
#  i: 309
#  i: 310
#  i: 311
#  i: 312
#  i: 313
#  i: 314
#  i: 315
#  i: 316
#  i: 317
#  i: 318
#  i: 319
#  i: 320
#  i: 321
#  i: 322
#  i: 323
#  i: 324
#  i: 325
#  i: 326
#  i: 327
#  i: 328
#  i: 329
#  i: 330
#  i: 331
#  i: 332
#  i: 333
#  i: 334
#  i: 335
#  i: 336
#  i: 337
#  i: 338
#  i: 339
#  i: 340
#  i: 341
#  i: 342
#  i: 343
#  i: 344
#  i: 345
#  i: 346
#  i: 347
#  i: 348
#  i: 349
#  i: 350
#  i: 351
#  i: 352
#  i: 353
#  i: 354
#  i: 355
#  i: 356
#  i: 357
#  i: 358
#  i: 359
#  i: 360
#  i: 361
#  i: 362
#  i: 363
#  i: 364
#  i: 365
#  i: 366
#  i: 367
#  i: 368
#  i: 369
#  i: 370
#  i: 371
#  i: 372
#  i: 373
#  i: 374
#  i: 375
#  i: 376
#  i: 377
#  i: 378
#  i: 379
#  i: 380
#  i: 381
#  i: 382
#  i: 383
#  i: 384
#  i: 385
#  i: 386
#  i: 387
#  i: 388
#  i: 389
#  i: 390
#  i: 391
#  i: 392
#  i: 393
#  i: 394
#  i: 395
#  i: 396
#  i: 397
#  i: 398
#  i: 399
#  i: 400
#  i: 401
#  i: 402
#  i: 403
#  i: 404
#  i: 405
#  i: 406
#  i: 407
#  i: 408
#  i: 409
#  i: 410
#  i: 411
#  i: 412
#  i: 413
#  i: 414
#  i: 415
#  i: 416
#  i: 417
#  i: 418
#  i: 419
#  i: 420
#  i: 421
#  i: 422
#  i: 423
#  i: 424
#  i: 425
#  i: 426
#  i: 427
#  i: 428
#  i: 429
#  i: 430
#  i: 431
#  i: 432
#  i: 433
#  i: 434
#  i: 435
#  i: 436
#  i: 437
#  i: 438
#  i: 439
#  i: 440
#  i: 441
#  i: 442
#  i: 443
#  i: 444
#  i: 445
#  i: 446
#  i: 447
#  i: 448
#  i: 449
#  i: 450
#  i: 451
#  i: 452
#  i: 453
#  i: 454
#  i: 455
#  i: 456
#  i: 457
#  i: 458
#  i: 459
#  i: 460
#  i: 461
#  i: 462
#  i: 463
#  i: 464
#  i: 465
#  i: 466
#  i: 467
#  i: 468
#  i: 469
#  i: 470
#  i: 471
#  i: 472
#  i: 473
#  i: 474
#  i: 475
#  i: 476
#  i: 477
#  i: 478
#  i: 479
#  i: 480
#  i: 481
#  i: 482
#  i: 483
#  i: 484
#  i: 485
#  i: 486
#  i: 487
#  i: 488
#  i: 489
#  i: 490
#  i: 491
#  i: 492
#  i: 493
#  i: 494
#  i: 495
#  i: 496
#  i: 497
#  i: 498
#  i: 499
#  i: 500
#  i: 501
#  i: 502
#  i: 503
#  i: 504
#  i: 505
#  i: 506
#  i: 507
#  i: 508
#  i: 509
#  i: 510
#  i: 511
#  i: 512
#  i: 513
#  i: 514
#  i: 515
#  i: 516
#  i: 517
#  i: 518
#  i: 519
#  i: 520
#  i: 521
#  i: 522
#  i: 523
#  i: 524
#  i: 525
#  i: 526
#  i: 527
#  i: 528
#  i: 529
#  i: 530
#  i: 531
#  i: 532
#  i: 533
#  i: 534
#  i: 535
#  i: 536
#  i: 537
#  i: 538
#  i: 539
#  i: 540
#  i: 541
#  i: 542
#  i: 543
#  i: 544
#  i: 545
#  i: 546
#  i: 547
#  i: 548
#  i: 549
#  i: 550
#  i: 551
#  i: 552
#  i: 553
#  i: 554
#  i: 555
#  i: 556
#  i: 557
#  i: 558
#  i: 559
#  i: 560
#  i: 561
#  i: 562
#  i: 563
#  i: 564
#  i: 565
#  i: 566
#  i: 567
#  i: 568
#  i: 569
#  i: 570
#  i: 571
#  i: 572
#  i: 573
#  i: 574
#  i: 575
#  i: 576
#  i: 577
#  i: 578
#  i: 579
#  i: 580
#  i: 581
#  i: 582
#  i: 583
#  i: 584
#  i: 585
#  i: 586
#  i: 587
#  i: 588
#  i: 589
#  i: 590
#  i: 591
#  i: 592
#  i: 593
#  i: 594
#  i: 595
#  i: 596
#  i: 597
#  i: 598
#  i: 599
#  i: 600
#  i: 601
#  i: 602
#  i: 603
#  i: 604
#  i: 605
#  i: 606
#  i: 607
#  i: 608
#  i: 609
#  i: 610
#  i: 611
#  i: 612
#  i: 613
#  i: 614
#  i: 615
#  i: 616
#  i: 617
#  i: 618
#  i: 619
#  i: 620
#  i: 621
#  i: 622
#  i: 623
#  i: 624
#  i: 625
#  i: 626
#  i: 627
#  i: 628
#  i: 629
#  i: 630
#  i: 631
#  i: 632
#  i: 633
#  i: 634
#  i: 635
#  i: 636
#  i: 637
#  i: 638
#  i: 639
#  i: 640
#  i: 641
#  i: 642
#  i: 643
#  i: 644
#  i: 645
#  i: 646
#  i: 647
#  i: 648
#  i: 649
#  i: 650
#  i: 651
#  i: 652
#  i: 653
#  i: 654
#  i: 655
#  i: 656
#  i: 657
#  i: 658
#  i: 659
#  i: 660
#  i: 661
#  i: 662
#  i: 663
#  i: 664
#  i: 665
#  i: 666
#  i: 667
#  i: 668
#  i: 669
#  i: 670
#  i: 671
#  i: 672
#  i: 673
#  i: 674
#  i: 675
#  i: 676
#  i: 677
#  i: 678
#  i: 679
#  i: 680
#  i: 681
#  i: 682
#  i: 683
#  i: 684
#  i: 685
#  i: 686
#  i: 687
#  i: 688
#  i: 689
#  i: 690
#  i: 691
#  i: 692
#  i: 693
#  i: 694
#  i: 695
#  i: 696
#  i: 697
#  i: 698
#  i: 699
#  i: 700
#  i: 701
#  i: 702
#  i: 703
#  i: 704
#  i: 705
#  i: 706
#  i: 707
#  i: 708
#  i: 709
#  i: 710
#  i: 711
#  i: 712
#  i: 713
#  i: 714
#  i: 715
#  i: 716
#  i: 717
#  i: 718
#  i: 719
#  i: 720
#  i: 721
#  i: 722
#  i: 723
#  i: 724
#  i: 725
#  i: 726
#  i: 727
#  i: 728
#  i: 729
#  i: 730
#  i: 731
#  i: 732
#  i: 733
#  i: 734
#  i: 735
#  i: 736
#  i: 737
#  i: 738
#  i: 739
#  i: 740
#  i: 741
#  i: 742
#  i: 743
#  i: 744
#  i: 745
#  i: 746

# %%
print(Individuals['VOHs(Soundex)'].sum()) # VOHs: 42968
print(Individuals['Volume'].sum()) # VOHs by ABCNY: 11807
print(Individuals.head())
print(Individuals['TP predicted by soundex'].sum()) # TPs captured by Soundex: 423
TP_percent = Individuals['TP predicted by soundex'].sum()/Individuals['# of TPs(Obtained)'].sum() 
print(TP_percent) # TP%(Soundex) = 65.99%
# Out:
# 42968
# 11807
#    index  Rec. No         Theme      Category  \
# 0    115      116  Combinations  Combinations
# 1    116      117  Combinations  Combinations
# 2    117      118  Combinations  Combinations
# 3    118      119  Combinations  Combinations
# 4    119      120  Combinations  Combinations
#
#                                          Subcategory Entity Type  \
# 0  All given name initials with space between eac...  Individual
# 1   1 special character removed and 2 words combined  Individual
# 2  1 special character added and 1 letter replace...  Individual
# 3  2 typos same word non adjacent and 1 letter re...  Individual
# 4           2 truncations and variation of 2 letters  Individual
#
#                                    List Name  \
# 0             andrey konstantinovich lugovoy
# 1  muhammad abd-al-qadir mutni assaf al-rawi
# 2      abd el kader mahmoud mohamed el sayed
# 3                   abubakar mohammed shekau
# 4            aiman muhammed rabi al-zawahiri
#
#                            Original List Name  \
# 0             lugovoy, andrey konstantinovich
# 1  al-rawi, muhammad abd-al-qadir mutni assaf
# 2      el sayed, abd el kader mahmoud mohamed
# 3                   shekau, abubakar mohammed
# 4            al-zawahiri, aiman muhammed rabi
#
#                             Name Variation  ACCUITY ID  # of TPs  Volume  \
# 0                    A.  K.  L U G O V O Y  AS00850517         1       7
# 1  MUHAMMAD ABDAL-QADIR MUTNIASSAF AL-RAWI  AS06223109         1      84
# 2     ABD-EL KADER MAHMUD MOHAMED EL SAYED  AS00022081         1      37
# 3                 ABOBEKAR M#HAMMED SHEKAU  AS00728855         1      12
# 4            AIMA MUHAMMAD RAB AL-JAWAHIRI  AS00020027         0      14
#
#    # of TPs(Obtained) Digits Removed                Name Variation First Last  \
# 0                   1                                   a.  k.  l u g o v o y
# 1                   1                 muhammad abdal-qadir mutniassaf al-rawi
# 2                   0              0     abd-el kader mahmud mohamed el sayed
# 3                   0                                abobekar m#hammed shekau
# 4                   0                           aima muhammad rab al-jawahiri
#
#                     Name Variation Clean  VOHs(DoubleMetaphone)  \
# 0                    a  k  l u g o v o y                    103
# 1  muhammad abdalqadir mutniassaf alrawi                    101
# 2    abdel kader mahmud mohamed el sayed                    320
# 3                abobekar mhammed shekau                     18
# 4           aima muhammad rab aljawahiri                    101
#
#    TP predicted by doublemetaphone  VOHs(Soundex)  TP predicted by soundex
# 0                                0             68                        0
# 1                                0            235                        0
# 2                                0            619                        0
# 3                                0            139                        0
# 4                                0            149                        0
# 423
# 0.6599063962558502

# %% [markdown]
# # Cosine Similarity(cutofff:0.5) with Levenshtein Distance(cutoff1:15, cutoff2:2)

# %%
true_pos_cos = []
voh_cos = []

# %%
# Cosine Similarity
def cosine_similarity(Test_data_sample, OFAC_list_Individuals, Cutoff, Lev_cutoff_1, Lev_cutoff_2):
    
    Individuals['VOHs(Cosine)'] = 0
    Individuals['TP predicted by Cosine'] = 0
    
    df_scores = pd.DataFrame(columns = {'row_score','OFAC_Name','Original List Name','List Name','Name Variation', 'TP predicted by Cosine','Transformation'})
    scores = []
    og_name = []
    test_name = []
    actual = []
    original_list_name_test = []
    list_name_test = []
    transformations = []
    
    list_var = Test_data_sample['Name Variation Clean'].to_list() # Name Variation Clean List
    list_name = OFAC_list_Individuals['OFAC_Name_Clean'].to_list() # OFAC Name Clean List

    # Converting strings to vectors to calculate cosine similarity score
    vectorizer = CountVectorizer()

    vectorizer.fit(list_name)
    
    vector1 = vectorizer.transform(list_var).toarray()
    vector2 = vectorizer.transform(list_name).toarray()

    for i in range(len(vector1)):## Test Variation
        count=0
        TP=0
        for j in range(len(vector2)):## OFAC List 
            
            row_score = dot(vector1[i], vector2[j])/(norm(vector1[i]) * norm(vector2[j]))
            ofac_name = OFAC_list_Individuals['OFAC_Name_Clean'][j]
            test_name_row = Test_data_sample['Name Variation Clean'][i]
            orignal_list_name = Test_data_sample['Original List Name'][i]
            list_name = Test_data_sample['List Name'][i] 
            transform = Test_data_sample['Subcategory'][i]
            lev_dist = jellyfish.levenshtein_distance(str(Test_data_sample['Name Variation Clean'][i]),str(OFAC_list_Individuals['OFAC_Name_Clean'][j]))
            row_actual = 0
            
            
            if row_score >= Cutoff:
                if lev_dist <= Lev_cutoff_1:
                    count+=1
                    if ofac_name == orignal_list_name or ofac_name == list_name:
                        row_actual = 1
                        TP+=1
                    
                    scores.append(row_score) # Cosine Score
                    og_name.append(ofac_name) # OFAC Name
                    test_name.append(test_name_row) # Name Variation Clean
                    actual.append(row_actual) # TP captured by Cosine and Levenshtein: 1 or 0
                    original_list_name_test.append(orignal_list_name) # Original List Name
                    list_name_test.append(list_name) # List Name 
                    transformations.append(transform) # Subcategory
                    
            else:
                if lev_dist <= Lev_cutoff_2:
                    count+=1
                    if ofac_name == orignal_list_name or ofac_name == list_name:
                        row_actual = 1
                        TP+=1
                                 
                    scores.append(row_score) # Cosine Score
                    og_name.append(ofac_name) # OFAC Name
                    test_name.append(test_name_row) # Name Variation Clean
                    actual.append(row_actual) # TP captured by Levenshtein: 1 or 0
                    original_list_name_test.append(orignal_list_name) # Original List Name
                    list_name_test.append(list_name) # List Name 
                    transformations.append(transform) # Subcategory
                
        Individuals['VOHs(Cosine)'].iloc[i] = count
        Individuals['TP predicted by Cosine'].iloc[i] = TP
        
    df_scores['row_score'] = scores
    df_scores['OFAC_Name'] = og_name
    df_scores['Original List Name'] = original_list_name_test
    df_scores['List Name'] = list_name_test
    df_scores['Name Variation'] = test_name
    df_scores['TP predicted by Cosine'] = actual
    df_scores['Transformation'] = transformations
    
    true_positive = sum(df_scores['TP predicted by Cosine'])
    true_pos_cos.append(true_positive)
    voh_cos.append(df_scores.shape[0])

#     df_scores.to_csv('df'+ str(Cutoff) + '.csv')
    
    return df_scores

# %%
df3 = cosine_similarity(Individuals,df_individuals,0.5,15,2)

# %%
print(true_pos_cos) # True Positives captured by cosine similarity with levenshtein: 384
print(voh_cos) # Total Volume of Hits: 1807
# Out:
# [384]
# [1807]

# %%
TP_percent = true_pos_cos[0]/Individuals['# of TPs(Obtained)'].sum()*100
TP_percent # TP%(Cosine) = 59.90%
# Out:
# 59.90639625585024

# %%
Individuals['# of TPs'].value_counts()
# Out:
# 1    648
# 0     85
# 2     14
# Name: # of TPs, dtype: int64

# %%
# Getting Count of Actual TPs per Theme
Test_data_theme = Individuals[Individuals['# of TPs(Obtained)'] != 0]['Theme'].value_counts().reset_index()
Test_data_theme
# Out:
#                                   index  Theme
# 0   Names where Name Parts are Modified    211
# 1         Special Characters and Spaces    100
# 2                        Name Additions     68
# 3                  Name Part Variations     56
# 4                        Modified Order     54
# 5                          Combinations     45
# 6                        Name Deletions     38
# 7                  Different Name Parts     28
# 8                                   IDs     27
# 9                      Positive Control      6
# 10                     Negative Control      3
# 11  Names where name parts are Modified      3
# 12                    Foreign Languages      2

# %%
new_df=Individuals[Individuals['# of TPs(Obtained)'] != 0]
# Considering only 641 Individuals as Actual True Positives

# %%
new_df.head()
# Out:
#    index  Rec. No         Theme      Category  \
# 0    115      116  Combinations  Combinations
# 1    116      117  Combinations  Combinations
# 5    120      121  Combinations  Combinations
# 6    121      122  Combinations  Combinations
# 8    123      124  Combinations  Combinations
#
#                                          Subcategory Entity Type  \
# 0  All given name initials with space between eac...  Individual
# 1   1 special character removed and 2 words combined  Individual
# 5         Truncation at the beginning, 1 compression  Individual
# 6  Removal of special characters, compression, an...  Individual
# 8  First / middle name swapped with 1 character r...  Individual
#
#                                            List Name  \
# 0                     andrey konstantinovich lugovoy
# 1          muhammad abd-al-qadir mutni assaf al-rawi
# 5                      jairo humberto lopera barbosa
# 6  muhammad hadi 'abd-al-rahman fayhan sharban al...
# 8                aleksey aleksandrovich kostrubitsky
#
#                                   Original List Name  \
# 0                    lugovoy, andrey konstantinovich
# 1         al-rawi, muhammad abd-al-qadir mutni assaf
# 5                     lopera barbosa, jairo humberto
# 6  al-_x0003_anzi, muhammad hadi _x0003_abd-al-ra...
# 8               kostrubitsky, aleksey aleksandrovich
#
#                                     Name Variation  ACCUITY ID  ...  \
# 0                            A.  K.  L U G O V O Y  AS00850517  ...
# 1          MUHAMMAD ABDAL-QADIR MUTNIASSAF AL-RAWI  AS06223109  ...
# 5                      AIRO HUMBERTOLOPERA BARBOSA  AS00178815  ...
# 6  AL MUHAMMADHADIABDALRAHMANFAYHAN SHARBAN ALANZI  AS00095739  ...
# 8               ALEKSANDROVICH ALEKSEY KOSTRUBITKY  AS00258040  ...
#
#    # of TPs(Obtained)  Digits Removed  \
# 0                   1
# 1                   1
# 5                   1
# 6                   1
# 8                   1
#
#                          Name Variation First Last  \
# 0                            a.  k.  l u g o v o y
# 1          muhammad abdal-qadir mutniassaf al-rawi
# 5                      airo humbertolopera barbosa
# 6  al muhammadhadiabdalrahmanfayhan sharban alanzi
# 8               aleksandrovich aleksey kostrubitky
#
#                               Name Variation Clean VOHs(DoubleMetaphone)  \
# 0                              a  k  l u g o v o y                   103
# 1            muhammad abdalqadir mutniassaf alrawi                   101
# 5                      airo humbertolopera barbosa                     5
# 6  al muhammadhadiabdalrahmanfayhan sharban alanzi                    58
# 8               aleksandrovich aleksey kostrubitky                    12
#
#   TP predicted by doublemetaphone  VOHs(Soundex)  TP predicted by soundex  \
# 0                               0             68                        0
# 1                               0            235                        0
# 5                               1              4                        1
# 6                               0             81                        0
# 8                               1            149                        1
#
#    VOHs(Cosine)  TP predicted by Cosine
# 0             0                       0
# 1             1                       0
# 5             2                       1
# 6             0                       0
# 8             0                       0
#
# [5 rows x 22 columns]

# %%
# Match_doublemetaphone stores the Count of Matches(TP predicted by doubleMetaphone) per Theme for Double Metaphone algorithm
# Similarly, Missed_doublemetaphone stores the Count of Name Variation missed by Double Metaphone algorithm
Match_doublemetaphone = new_df[new_df['TP predicted by doublemetaphone'] != 0].Theme.value_counts().to_frame().reset_index()
Match_soundex = new_df[new_df['TP predicted by soundex'] != 0].Theme.value_counts().to_frame().reset_index()
Match_cosine = new_df[new_df['TP predicted by Cosine'] != 0].Theme.value_counts().to_frame().reset_index()
Missed_doublemetaphone = new_df[new_df['TP predicted by doublemetaphone'] == 0].Theme.value_counts().to_frame().reset_index()
Missed_soundex = new_df[new_df['TP predicted by soundex'] == 0].Theme.value_counts().to_frame().reset_index()
Missed_cosine = new_df[new_df['TP predicted by Cosine'] == 0].Theme.value_counts().to_frame().reset_index()

# %%
# Theme_VOHs_doubleMetaphone stores the count of total Volume of Hits generated under each Theme by 
# Double Metaphone algorithm for all 741 Name Variations
Theme_VOHs_doubleMetaphone = Individuals.groupby(by=['Theme'])['VOHs(DoubleMetaphone)'].sum().to_frame().reset_index()
Theme_VOHs_soundex = Individuals.groupby(by=['Theme'])['VOHs(Soundex)'].sum().to_frame().reset_index()
Theme_VOHs_cosine = Individuals.groupby(by=['Theme'])['VOHs(Cosine)'].sum().to_frame().reset_index()

# %%
Theme_VOHs_cosine
# Out:
#                                   Theme  VOHs(Cosine)
# 0                          Combinations           165
# 1                  Different Name Parts            96
# 2                     Foreign Languages             0
# 3                                   IDs             0
# 4                        Modified Order           130
# 5                        Name Additions           108
# 6                        Name Deletions            51
# 7                  Name Part Variations           279
# 8   Names where Name Parts are Modified           679
# 9   Names where name parts are Modified             3
# 10                     Negative Control             8
# 11                     Positive Control            22
# 12        Special Characters and Spaces           266

# %%
# Merges the Volume of Hits per theme for all the Algorithms in a single dataframe
MergedVOHs = pd.merge(pd.merge(Theme_VOHs_doubleMetaphone, Theme_VOHs_soundex, on='Theme', how='left'),Theme_VOHs_cosine, on='Theme', how='left')

# %%
# Merges the TP count per theme for all the Algorithms in a single dataframe 
MergedTP = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(Test_data_theme, Match_doublemetaphone, on='index', how='left'),Missed_doublemetaphone, on='index',how='left'),Match_soundex,on='index', how='left'),Missed_soundex, on='index',how='left'), Match_cosine, on='index',how='left'), Missed_cosine, on='index',how='left')

# %%
# Naming the columns for MergeTP
MergedTP.columns=['Theme','# of TP(Obtained)','Matched(DoubleMetaphone)','Missed(DoubleMetaphone)','Matched(Soundex)','Missed(Soundex)','Matched(Cosine)','Missed(Cosine)']

# %%
# Finding TP% under each Theme for all Algorithms
for i in range(len(MergedTP)):
    MergedTP.loc[i, 'TP%(DoubleMetaphone)'] = round(MergedTP['Matched(DoubleMetaphone)'][i]/MergedTP['# of TP(Obtained)'][i]*100,2)
    MergedTP.loc[i, 'TP%(Soundex)'] = round(MergedTP['Matched(Soundex)'][i]/MergedTP['# of TP(Obtained)'][i]*100,2)
    MergedTP.loc[i, 'TP%(Cosine)'] = round(MergedTP['Matched(Cosine)'][i]/MergedTP['# of TP(Obtained)'][i]*100, 2)

# %%
# Merging the Volume of Hits and TP% dataframes
Metrics = pd.merge(MergedVOHs, MergedTP, on='Theme',how='left')

# %%
Metrics = Metrics.reindex(columns=['Theme','# of TP(Obtained)','Matched(DoubleMetaphone)','Missed(DoubleMetaphone)','TP%(DoubleMetaphone)','VOHs(DoubleMetaphone)','Matched(Soundex)','Missed(Soundex)','TP%(Soundex)','VOHs(Soundex)','Matched(Cosine)','Missed(Cosine)','TP%(Cosine)','VOHs(Cosine)'])

# %%
Metrics
# Out:
#                                   Theme  # of TP(Obtained)  \
# 0                          Combinations                 45
# 1                  Different Name Parts                 28
# 2                     Foreign Languages                  2
# 3                                   IDs                 27
# 4                        Modified Order                 54
# 5                        Name Additions                 68
# 6                        Name Deletions                 38
# 7                  Name Part Variations                 56
# 8   Names where Name Parts are Modified                211
# 9   Names where name parts are Modified                  3
# 10                     Negative Control                  3
# 11                     Positive Control                  6
# 12        Special Characters and Spaces                100
#
#     Matched(DoubleMetaphone)  Missed(DoubleMetaphone)  TP%(DoubleMetaphone)  \
# 0                       21.0                       24                 46.67
# 1                       11.0                       17                 39.29
# 2                        NaN                        2                   NaN
# 3                        NaN                       27                   NaN
# 4                       44.0                       10                 81.48
# 5                       55.0                       13                 80.88
# 6                       23.0                       15                 60.53
# 7                       45.0                       11                 80.36
# 8                      162.0                       49                 76.78
# 9                        NaN                        3                   NaN
# 10                       NaN                        3                   NaN
# 11                       5.0                        1                 83.33
# 12                      51.0                       49                 51.00
#
#     VOHs(DoubleMetaphone)  Matched(Soundex)  Missed(Soundex)  TP%(Soundex)  \
# 0                    2520              23.0               22         51.11
# 1                    2983              11.0               17         39.29
# 2                       0               NaN                2           NaN
# 3                      54               NaN               27           NaN
# 4                    2245              44.0               10         81.48
# 5                    3831              55.0               13         80.88
# 6                    2363              23.0               15         60.53
# 7                    2023              45.0               11         80.36
# 8                    4944             162.0               49         76.78
# 9                     273               NaN                3           NaN
# 10                     17               NaN                3           NaN
# 11                     94               5.0                1         83.33
# 12                   2937              55.0               45         55.00
#
#     VOHs(Soundex)  Matched(Cosine)  Missed(Cosine)  TP%(Cosine)  VOHs(Cosine)
# 0            4153             18.0              27        40.00           165
# 1            4384             11.0              17        39.29            96
# 2              12              NaN               2          NaN             0
# 3             149              NaN              27          NaN             0
# 4            3858             37.0              17        68.52           130
# 5            5962             48.0              20        70.59           108
# 6            4471             22.0              16        57.89            51
# 7            3247             48.0               8        85.71           279
# 8           10502            156.0              55        73.93           679
# 9             302              NaN               3          NaN             3
# 10             60              NaN               3          NaN             8
# 11            288              5.0               1        83.33            22
# 12           5580             39.0              61        39.00           266

# %%
Metrics.to_excel('Metrics.xlsx')

# %%
Individuals.to_excel('Individuals.xlsx')
